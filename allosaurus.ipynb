# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# MERGING AUDIO FOLDERS

# %%
import os
import shutil

def merge_folders(source_folders, target_folder):
    os.makedirs(target_folder, exist_ok=True)

    for folder in source_folders:
        if not os.path.exists(folder):
            print(f"Skipping non-existent folder: {folder}")
            continue

        for file_name in os.listdir(folder):
            source_path = os.path.join(folder, file_name)
            target_path = os.path.join(target_folder, file_name)

            if os.path.isfile(source_path):
                if os.path.exists(target_path):
                    base, ext = os.path.splitext(file_name)
                    counter = 1
                    new_target_path = os.path.join(target_folder, f"{base}_{counter}{ext}")

                    while os.path.exists(new_target_path):
                        counter += 1
                        new_target_path = os.path.join(target_folder, f"{base}_{counter}{ext}")

                    target_path = new_target_path

                shutil.move(source_path, target_path)
                print(f"Moved: {source_path} -> {target_path}")

def delete_json_files(folder):
    if not os.path.exists(folder):
        print(f"Folder does not exist: {folder}")
        return

    for file_name in os.listdir(folder):
        file_path = os.path.join(folder, file_name)
        if os.path.isfile(file_path) and file_name.endswith(".json"):
            os.remove(file_path)
            print(f"Deleted: {file_path}")

# Example usage
source_folders = ["/content/drive/MyDrive/Dataset/Validate/lifecycle/281474976710766"]  # Replace with actual folder paths
target_folder = "/content/drive/MyDrive/Dataset/Validate/lifecycle"
merge_folders(source_folders, target_folder)

delete_json_files(target_folder)

# %% [markdown]
# # EDA

# %%
import os
import pandas as pd

def check_missing_transcriptions(csv_path, audio_dir):
    # Load CSV file
    df = pd.read_csv(csv_path)
    existing_ids = set(df['ID'].astype(str))

    # List all .wav files in the directory
    audio_files = {os.path.splitext(f)[0] for f in os.listdir(audio_dir) if f.endswith('.wav')}

    # Check for missing transcriptions
    missing = audio_files - existing_ids

    if missing:
        print(f"Missing transcriptions for {len(missing)} files in {audio_dir}:", missing)
    else:
        print(f"All audio files in {audio_dir} have transcriptions.")


# Example usage
check_missing_transcriptions('/content/drive/MyDrive/Dataset/Train/train.csv', '/content/drive/MyDrive/Dataset/Train/translation')
check_missing_transcriptions('/content/drive/MyDrive/Dataset/Validate/validate.csv', '/content/drive/MyDrive/Dataset/Validate/lifecycle')
# Out:
# Missing transcriptions for 2333 files in /content/drive/MyDrive/Dataset/Train/translation: {'281474976731242', '281474976728434', '281474976730249', '281474976729997', '281474976729832', '281474976731287', '281474976728417', '281474976731310', '281474976728470', '281474976717754', '281474976730563', '281474976727360', '281474976729610', '281474976730965', '281474976730257', '281474976729734', '281474976731095', '281474976727243', '281474976728706', '281474976730979', '281474976728696', '281474976729648', '281474976727312', '281474976728565', '281474976731038', '281474976728356', '281474976730491', '281474976730372', '281474976729613', '281474976729704', '281474976728513', '281474976729059', '281474976731067', '281474976729674', '281474976728602', '281474976729804', '281474976729055', '281474976728459', '281474976729514', '281474976730415', '281474976731087', '281474976729068', '281474976730327', '281474976728767', '281474976728799', '281474976728627', '281474976728737', '281474976731265', '281474976731029', '281474976728639', '281474976729021', '281474976727298', '281474976730353', '281474976731249', '281474976729531', '281474976728621', '281474976727263', '281474976728451', '281474976728638', '281474976729767', '281474976731252', '281474976729801', '281474976728930', '281474976731200', '281474976730250', '281474976728442', '281474976730325', '281474976729534', '281474976728496', '281474976729503', '281474976729819', '281474976728616', '281474976728405', '281474976728871', '281474976730264', '281474976729010', '281474976731262', '281474976730988', '281474976730365', '281474976730246', '281474976728653', '281474976729689', '281474976728847', '281474976729828', '281474976728633', '281474976729043', '281474976731022', '281474976730427', '281474976730477', '281474976728678', '281474976727468', '281474976730234', '281474976731180', '281474976729499', '281474976728858', '281474976717938', '281474976730371', '281474976730357', '281474976729085', '281474976727287', '281474976728815', '281474976727486', '281474976728426', '281474976729647', '281474976731076', '281474976728506', '281474976729541', '281474976727238', '281474976728885', '281474976727562', '281474976728485', '281474976727535', '281474976728697', '281474976729760', '281474976731284', '281474976729073', '281474976728401', '281474976729488', '281474976728686', '281474976728425', '281474976728985', '281474976727560', '281474976730333', '281474976730966', '281474976729874', '281474976729805', '281474976727013', '281474976731218', '281474976729530', '281474976728597', '281474976730559', '281474976727460', '281474976729511', '281474976730510', '281474976728691', '281474976730412', '281474976727447', '281474976727356', '281474976728399', '281474976717854', '281474976727564', '281474976729698', '281474976730226', '281474976727558', '281474976728514', '281474976729712', '281474976728604', '281474976729061', '281474976728817', '281474976728741', '281474976731049', '281474976730575', '281474976727380', '281474976729025', '281474976731296', '281474976727549', '281474976730358', '281474976730452', '281474976728911', '281474976729666', '281474976730317', '281474976729791', '281474976730288', '281474976728351', '281474976731159', '281474976729831', '281474976730314', '281474976730227', '281474976727448', '281474976728369', '281474976729516', '281474976730438', '281474976717796', '281474976727494', '281474976730216', '281474976731015', '281474976728862', '281474976730993', '281474976728924', '281474976730468', '281474976729998', '281474976717830', '281474976728735', '281474976727313', '281474976731317', '281474976731301', '281474976728608', '281474976730969', '281474976730268', '281474976730429', '281474976727316', '281474976727464', '281474976730278', '281474976728601', '281474976729825', '281474976731204', '281474976728592', '281474976728560', '281474976730398', '281474976728866', '281474976728844', '281474976728788', '281474976730303', '281474976730344', '281474976728772', '281474976730 ...
# Missing transcriptions for 8 files in /content/drive/MyDrive/Dataset/Validate/lifecycle: {'281474976733588', '281474976733745', '281474976733744', '281474976735659', '281474976734763', '281474976734731', '281474976734760', '281474976734758'}

# %%
import os

def count_wav_files(directory):
    return len([file for file in os.listdir(directory) if file.lower().endswith('.wav')])

# Example usage
directory_path = "/content/drive/MyDrive/Dataset/Validate/lifecycle"  # Change this to your actual directory
wav_count = count_wav_files(directory_path)
print(f"Number of WAV files: {wav_count}")
# Out:
# Number of WAV files: 299

# %%
import os
import pandas as pd

def check_missing_audio(csv_path, audio_dir):
    # Load CSV file
    df = pd.read_csv(csv_path)

    # Ensure 'ID' column exists
    if 'ID' not in df.columns:
        raise ValueError("CSV file must contain a column named 'ID'")

    # Generate expected filenames
    df['Filename'] = df['ID'].astype(str) + '.wav'

    # Check for missing files
    missing_files = [fname for fname in df['Filename'] if not os.path.exists(os.path.join(audio_dir, fname))]

    # Print missing files
    if missing_files:
        print("Missing files:")
        for file in missing_files:
            print(file)
    else:
        print("All files exist.")

    # Print count of missing files
    print(f"Total missing files: {len(missing_files)}")

    return missing_files

# Example usage
csv_path = "/content/drive/MyDrive/Dataset/Train/train.csv"  # Replace with actual CSV file path
audio_dir = "/content/drive/MyDrive/Dataset/Train/translation"  # Replace with actual audio directory path
missing_files = check_missing_audio(csv_path, audio_dir)

# %%
import os

# Define the directory to check
directory = "/content/drive/MyDrive/Dataset/Train/translation"  # Change this to your actual directory

# List of filenames to check
filenames = [
    "281474976733829.wav", "281474976733611.wav", "281474976735670.wav",
    "281474976734720.wav", "281474976733782.wav", "281474976734029.wav",
    "281474976734743.wav", "281474976733752.wav", "281474976733840.wav",
    "281474976735756.wav", "281474976734789.wav", "281474976733982.wav",
    "281474976734010.wav", "281474976733330.wav", "281474976734759.wav",
    "281474976734106.wav", "281474976735658.wav", "281474976734037.wav",
    "281474976734778.wav", "281474976734749.wav", "281474976734096.wav",
    "281474976733336.wav", "281474976734757.wav", "281474976734099.wav",
    "281474976733980.wav", "281474976733851.wav", "281474976733822.wav",
    "281474976733850.wav", "281474976734046.wav", "281474976734740.wav",
    "281474976733623.wav", "281474976734738.wav", "281474976733772.wav",
    "281474976733987.wav", "281474976733779.wav", "281474976733328.wav",
    "281474976735770.wav", "281474976735668.wav", "281474976733326.wav",
    "281474976734120.wav", "281474976734024.wav", "281474976734725.wav",
    "281474976734766.wav", "281474976734773.wav", "281474976735666.wav",
    "281474976733616.wav", "281474976734019.wav", "281474976733843.wav",
    "281474976734776.wav", "281474976734098.wav", "281474976733329.wav",
    "281474976734793.wav", "281474976734102.wav", "281474976734003.wav",
    "281474976735769.wav", "281474976733589.wav", "281474976733599.wav",
    "281474976734756.wav", "281474976733854.wav", "281474976734724.wav",
    "281474976735751.wav", "281474976734001.wav", "281474976734742.wav",
    "281474976733768.wav", "281474976735673.wav", "281474976734791.wav",
    "281474976735740.wav", "281474976735746.wav", "281474976733833.wav",
    "281474976733325.wav", "281474976734000.wav", "281474976734786.wav",
    "281474976733844.wav", "281474976733322.wav", "281474976735747.wav",
    "281474976733598.wav", "281474976734017.wav", "281474976735662.wav",
    "281474976733846.wav", "281474976734035.wav", "281474976735753.wav",
    "281474976735771.wav", "281474976733605.wav", "281474976733760.wav",
    "281474976733617.wav", "281474976733596.wav", "281474976734739.wav",
    "281474976734113.wav", "281474976733346.wav", "281474976733762.wav",
    "281474976735742.wav", "281474976734775.wav", "281474976734783.wav",
    "281474976733749.wav", "281474976733834.wav", "281474976733750.wav",
    "281474976733765.wav", "281474976733323.wav", "281474976733841.wav",
    "281474976734032.wav", "281474976733756.wav", "281474976733981.wav",
    "281474976733593.wav", "281474976734006.wav", "281474976733757.wav",
    "281474976734729.wav", "281474976734728.wav", "281474976735738.wav",
    "281474976734119.wav", "281474976735667.wav", "281474976734762.wav",
    "281474976734735.wav", "281474976735772.wav", "281474976734128.wav",
    "281474976735761.wav", "281474976733857.wav", "281474976734727.wav",
    "281474976733315.wav", "281474976734785.wav", "281474976733998.wav",
    "281474976734754.wav", "281474976734118.wav", "281474976733985.wav",
    "281474976734031.wav", "281474976735759.wav", "281474976733995.wav",
    "281474976735758.wav", "281474976734026.wav", "281474976734052.wav",
    "281474976734123.wav", "281474976733317.wav", "281474976734781.wav",
    "281474976733764.wav", "281474976734764.wav", "281474976734737.wav",
    "281474976733748.wav", "281474976733332.wav", "281474976733778.wav",
    "281474976733625.wav", "281474976733603.wav", "281474976733331.wav",
    "281474976735760.wav", "281474976733825.wav", "281474976735762.wav",
    "281474976733590.wav", "281474976733830.wav", "281474976734753.wav",
    "281474976734748.wav", "281474976733860.wav", "281474976733755.wav",
    "281474976734007.wav", "281474976734745.wav", "281474976733770.wav",
    "281474976735657.wav", "281474976734015.wav", "281474976734765.wav",
    "281474976733350.wav", "281474976735754.wav", "281474976733333.wav",
    "281474976733318.wav", "281474976733345.wav", "281474976734002.wav",
    "281474976733613.wav", "281474976734787.wav", "281474976735674.wav",
    "281474976734009.wav", "281474976734011.wav", "281474976734116.wav",
    "281474976733855.wav", "281474976733853.wav", "281474976733594.wav",
    "281474976734110.wav", "281474976734117.wav", "281474976733321.wav",
    "281474976733347.wav", "281474976733343.wav", "281474976733993.wav",
    "281474976733609.wav", "281474976735739.wav", "281474976733607.wav",
    "281474976734045.wav", "281474976734722.wav", "281474976733984.wav",
    "281474976734103.wav", "281474976733773.wav", "281474976733978.wav",
    "281474976733327.wav", "281474976733761.wav", "281474976735749.wav",
    "281474976734025.wav", "281474976733826.wav", "281474976733320.wav"
]

# Check if files exist and print missing ones
missing_files = [filename for filename in filenames if not os.path.exists(os.path.join(directory, filename))]

# Print missing files
if missing_files:
    print("Missing files:")
    for file in missing_files:
        print(file)
else:
    print("All files exist.")
# Out:
# All files exist.

# %%
import os
import shutil

# Define source and destination directories
source_dir = "/content/drive/MyDrive/Dataset/Validate/lifecycle"  # Change this to your source directory
destination_dir = "/content/drive/MyDrive/Dataset//Train/translation"  # Change this to your destination directory
missing_files_log = "missing_files.txt"

# List of filenames to move
filenames = [
    "281474976733829.wav", "281474976733611.wav", "281474976735670.wav",
    "281474976734720.wav", "281474976733782.wav", "281474976734029.wav",
    "281474976734743.wav", "281474976733752.wav", "281474976733840.wav",
    "281474976735756.wav", "281474976734789.wav", "281474976733982.wav",
    "281474976734010.wav", "281474976733330.wav", "281474976734759.wav",
    "281474976734106.wav", "281474976735658.wav", "281474976734037.wav",
    "281474976734778.wav", "281474976734749.wav", "281474976734096.wav",
    "281474976733336.wav", "281474976734757.wav", "281474976734099.wav",
    "281474976733980.wav", "281474976733851.wav", "281474976733822.wav",
    "281474976733850.wav", "281474976734046.wav", "281474976734740.wav",
    "281474976733623.wav", "281474976734738.wav", "281474976733772.wav",
    "281474976733987.wav", "281474976733779.wav", "281474976733328.wav",
    "281474976735770.wav", "281474976735668.wav", "281474976733326.wav",
    "281474976734120.wav", "281474976734024.wav", "281474976734725.wav",
    "281474976734766.wav", "281474976734773.wav", "281474976735666.wav",
    "281474976733616.wav", "281474976734019.wav", "281474976733843.wav",
    "281474976734776.wav", "281474976734098.wav", "281474976733329.wav",
    "281474976734793.wav", "281474976734102.wav", "281474976734003.wav",
    "281474976735769.wav", "281474976733589.wav", "281474976733599.wav",
    "281474976734756.wav", "281474976733854.wav", "281474976734724.wav",
    "281474976735751.wav", "281474976734001.wav", "281474976734742.wav",
    "281474976733768.wav", "281474976735673.wav", "281474976734791.wav",
    "281474976735740.wav", "281474976735746.wav", "281474976733833.wav",
    "281474976733325.wav", "281474976734000.wav", "281474976734786.wav",
    "281474976733844.wav", "281474976733322.wav", "281474976735747.wav",
    "281474976733598.wav", "281474976734017.wav", "281474976735662.wav",
    "281474976733846.wav", "281474976734035.wav", "281474976735753.wav",
    "281474976735771.wav", "281474976733605.wav", "281474976733760.wav",
    "281474976733617.wav", "281474976733596.wav", "281474976734739.wav",
    "281474976734113.wav", "281474976733346.wav", "281474976733762.wav",
    "281474976735742.wav", "281474976734775.wav", "281474976734783.wav",
    "281474976733749.wav", "281474976733834.wav", "281474976733750.wav",
    "281474976733765.wav", "281474976733323.wav", "281474976733841.wav",
    "281474976734032.wav", "281474976733756.wav", "281474976733981.wav",
    "281474976733593.wav", "281474976734006.wav", "281474976733757.wav",
    "281474976734729.wav", "281474976734728.wav", "281474976735738.wav",
    "281474976734119.wav", "281474976735667.wav", "281474976734762.wav",
    "281474976734735.wav", "281474976735772.wav", "281474976734128.wav",
    "281474976735761.wav", "281474976733857.wav", "281474976734727.wav",
    "281474976733315.wav", "281474976734785.wav", "281474976733998.wav",
    "281474976734754.wav", "281474976734118.wav", "281474976733985.wav",
    "281474976734031.wav", "281474976735759.wav", "281474976733995.wav",
    "281474976735758.wav", "281474976734026.wav", "281474976734052.wav",
    "281474976734123.wav", "281474976733317.wav", "281474976734781.wav",
    "281474976733764.wav", "281474976734764.wav", "281474976734737.wav",
    "281474976733748.wav", "281474976733332.wav", "281474976733778.wav",
    "281474976733625.wav", "281474976733603.wav", "281474976733331.wav",
    "281474976735760.wav", "281474976733825.wav", "281474976735762.wav",
    "281474976733590.wav", "281474976733830.wav", "281474976734753.wav",
    "281474976734748.wav", "281474976733860.wav", "281474976733755.wav",
    "281474976734007.wav", "281474976734745.wav", "281474976733770.wav",
    "281474976735657.wav", "281474976734015.wav", "281474976734765.wav",
    "281474976733350.wav", "281474976735754.wav", "281474976733333.wav",
    "281474976733318.wav", "281474976733345.wav", "281474976734002.wav",
    "281474976733613.wav", "281474976734787.wav", "281474976735674.wav",
    "281474976734009.wav", "281474976734011.wav", "281474976734116.wav",
    "281474976733855.wav", "281474976733853.wav", "281474976733594.wav",
    "281474976734110.wav", "281474976734117.wav", "281474976733321.wav",
    "281474976733347.wav", "281474976733343.wav", "281474976733993.wav",
    "281474976733609.wav", "281474976735739.wav", "281474976733607.wav",
    "281474976734045.wav", "281474976734722.wav", "281474976733984.wav",
    "281474976734103.wav", "281474976733773.wav", "281474976733978.wav",
    "281474976733327.wav", "281474976733761.wav", "281474976735749.wav",
    "281474976734025.wav", "281474976733826.wav", "281474976733320.wav"
]

# The rest of the script remains unchanged...
missing_files = []

# Ensure the destination directory exists
os.makedirs(destination_dir, exist_ok=True)

# Move files and log missing ones
for filename in filenames:
    source_path = os.path.join(source_dir, filename)
    destination_path = os.path.join(destination_dir, filename)

    if os.path.exists(source_path):
        shutil.move(source_path, destination_path)
        print(f"Moved: {filename}")
    else:
        print(f"Missing: {filename}")
        missing_files.append(filename)

# Write missing files to a log file
if missing_files:
    with open(missing_files_log, "w") as f:
        for file in missing_files:
            f.write(file + "\n")

    print(f"Missing files list saved to {missing_files_log}")

print("File transfer complete.")

# %%
import os
import shutil

# Define source and destination directories
source_dir = "/content/drive/MyDrive/Dataset/Validate/lifecycle"  # Change this to your source directory
destination_dir = "/content/drive/MyDrive/Dataset/Train/translation"  # Change this to your destination directory
missing_files_log = "missing_files.txt"

# List of filenames to move
filenames = [
    "281474976734020.wav", "281474976733776.wav", "281474976735671.wav", "281474976734109.wav", "281474976733614.wav", "281474976734030.wav", "281474976735765.wav", "281474976734129.wav", "281474976735737.wav", "281474976733824.wav", "281474976733852.wav", "281474976733339.wav", "281474976733334.wav", "281474976733338.wav", "281474976733836.wav", "281474976733753.wav", "281474976734792.wav", "281474976733620.wav", "281474976735669.wav", "281474976733777.wav", "281474976735672.wav", "281474976734036.wav", "281474976734005.wav", "281474976733626.wav", "281474976733353.wav", "281474976733612.wav", "281474976733747.wav", "281474976733600.wav", "281474976734796.wav", "281474976734004.wav", "281474976734771.wav", "281474976733989.wav", "281474976733845.wav", "281474976734751.wav", "281474976734732.wav", "281474976734111.wav", "281474976733990.wav", "281474976733618.wav", "281474976733983.wav", "281474976734016.wav", "281474976735745.wav", "281474976733758.wav", "281474976734105.wav", "281474976734126.wav", "281474976733759.wav", "281474976734042.wav", "281474976733591.wav", "281474976733604.wav", "281474976734013.wav", "281474976734131.wav", "281474976735741.wav", "281474976734723.wav", "281474976734752.wav", "281474976734022.wav", "281474976733839.wav", "281474976734115.wav", "281474976733754.wav", "281474976733351.wav", "281474976734034.wav", "281474976733602.wav", "281474976733781.wav", "281474976734130.wav", "281474976733341.wav", "281474976734782.wav", "281474976734761.wav", "281474976733597.wav", "281474976735748.wav", "281474976734108.wav", "281474976733622.wav", "281474976733621.wav", "281474976734012.wav", "281474976733994.wav", "281474976734041.wav", "281474976734124.wav", "281474976734741.wav", "281474976733842.wav", "281474976734734.wav", "281474976734047.wav", "281474976734122.wav", "281474976734772.wav", "281474976734014.wav", "281474976735661.wav", "281474976733838.wav", "281474976734038.wav", "281474976735660.wav", "281474976733746.wav", "281474976733608.wav", "281474976733610.wav", "281474976735757.wav", "281474976734021.wav", "281474976733988.wav", "281474976734770.wav", "281474976733352.wav", "281474976733766.wav", "281474976733828.wav", "281474976734055.wav", "281474976735763.wav", "281474976735744.wav", "281474976733849.wav", "281474976734719.wav", "281474976733859.wav", "281474976734795.wav", "281474976735755.wav", "281474976734049.wav", "281474976733997.wav", "281474976735766.wav", "281474976733999.wav", "281474976734750.wav", "281474976734790.wav", "281474976735768.wav", "281474976735767.wav", "281474976735736.wav", "281474976733342.wav", "281474976733601.wav", "281474976734125.wav", "281474976734008.wav", "281474976734121.wav", "281474976733595.wav", "281474976734023.wav", "281474976734744.wav", "281474976733335.wav", "281474976733992.wav", "281474976734747.wav", "281474976733624.wav", "281474976733856.wav", "281474976734127.wav", "281474976735743.wav", "281474976734733.wav"
]

missing_files = []

# Ensure the destination directory exists
os.makedirs(destination_dir, exist_ok=True)

# Move files and log missing ones
for filename in filenames:
    source_path = os.path.join(source_dir, filename)
    destination_path = os.path.join(destination_dir, filename)

    if os.path.exists(source_path):
        shutil.move(source_path, destination_path)
        print(f"Moved: {filename}")
    else:
        print(f"Missing: {filename}")
        missing_files.append(filename)

# Write missing files to a log file
if missing_files:
    with open(missing_files_log, "w") as f:
        for file in missing_files:
            f.write(file + "\n")

    print(f"Missing files list saved to {missing_files_log}")

print("File transfer complete.")

# %%
import os
import pandas as pd

def check_and_delete_missing_transcriptions(csv_path, audio_dir):
    # Load CSV file
    df = pd.read_csv(csv_path)
    existing_ids = set(df['ID'].astype(str))

    # List all .wav files in the directory
    audio_files = {os.path.splitext(f)[0] for f in os.listdir(audio_dir) if f.endswith('.wav')}

    # Identify missing transcriptions
    missing = audio_files - existing_ids
    missing_count = len(missing)

    if missing:
        print(f"Found {missing_count} audio files without transcriptions in {audio_dir}. Deleting them now...")
        for missing_file in missing:
            file_path = os.path.join(audio_dir, f"{missing_file}.wav")
            try:
                os.remove(file_path)
                print(f"Deleted: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")
        print(f"Total {missing_count} files deleted from {audio_dir}.")
    else:
        print(f"All {len(audio_files)} audio files in {audio_dir} have transcriptions.")

# Example usage
check_and_delete_missing_transcriptions('/content/drive/MyDrive/Dataset/Train/train.csv', '/content/drive/MyDrive/Dataset/Train/translation')
check_and_delete_missing_transcriptions('/content/drive/MyDrive/Dataset/Validate/validate.csv', '/content/drive/MyDrive/Dataset/Validate/lifecycle')

# %% [markdown]
# DEVNAGARI TO IPA

# %%
# !python -m allosaurus.bin.list_phone --lang hin
# Out:
# a aː b bː b̤ b̤ː d̠ d̤ d̪ d̪ː d̪̤ d̪̤ː d̻ e eː e̯ f fː h i iː j jː k kʰ kʰː kː l lː l̤ l̪ l̪̤ l̻ m mː m̤ n nː n̪ n̪ː n̪̤ n̻ o oː o̯ p pʰ pʰː pː q qː r rː r̪ s sː s̪ t̠ t̪ t̪ʰ t̪ʰː t̪ː t̻ u uː w z zː z̪ æ æː ŋ ŋː ɑ ɑ̃ ɔ ɔː ɔ̃ ɔ̃ː ɔ̤ ɖ ɖː ɖ̤ ɖ̤ː ə ə̃ ɛ ɛː ɛ̃ ɛ̃ː ɜ ɜ̃ ɟ ɟ̤ ɡ ɡː ɡ̤ ɡ̤ː ɦ ɪ ɪ̃ ɪ̈ ɲ ɳ ɽ ɽ̃ ɽ̤ ɾ ʁ ʂ ʃ ʃʰ ʃʰː ʃː ʈ ʈʰ ʈʰː ʈː ʊ ʊ̃ ʋ ʋː ʒ ʒː ʒ̤ ʒ̤ː ʔ ʝ β̞ χ

# %%
# !pip install indic-transliteration
# Out:
# Requirement already satisfied: indic-transliteration in /usr/local/lib/python3.11/dist-packages (2.3.69)
# Requirement already satisfied: backports.functools-lru-cache in /usr/local/lib/python3.11/dist-packages (from indic-transliteration) (2.0.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from indic-transliteration) (2024.11.6)
# Requirement already satisfied: typer in /usr/local/lib/python3.11/dist-packages (from indic-transliteration) (0.15.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from indic-transliteration) (0.10.2)
# Requirement already satisfied: roman in /usr/local/lib/python3.11/dist-packages (from indic-transliteration) (5.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer->indic-transliteration) (8.1.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from typer->indic-transliteration) (4.13.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer->indic-transliteration) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer->indic-transliteration) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer->indic-transliteration) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer->indic-transliteration) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->indic-transliteration) (0.1.2)

# %%
with open("/content/drive/MyDrive/Dataset/train/train.csv", encoding="utf-8") as f:
    for i in range(5):
        print(f.readline())
# Out:
# ID,IPA_Transcription
#
# 281474976729909,ʈ iː ʈ oː k ɛː s ɛː ɡ ɪ ɾ oː
#
# 281474976729966,m ɛː ɦ ə ɾ ə d̪ ɪ n aː ə l t̪ ə ə l t̪ ə ɦ ɛː ɾ aː n ə ɦ ɛː ɡ ə uː
#
# 281474976717958,t̪ ʊ m ə k ə l l ɪ b ə eː ɛː k ɪ t̪ aː b ə d̪ ɛː d̪ ɛː ɡ eː
#
# 281474976730085,m ɛː b aː eː ɛː eː k ə b ə aː d̪ ɛː ɾ ə uː

# %%
import pandas as pd
from indic_transliteration.sanscript import transliterate, DEVANAGARI, IAST
import re

# Hindi phoneme inventory (simplified for filtering)
hindi_inventory = set([
    "a", "aː", "b", "bː", "b̤", "b̤ː", "d̪", "d̪ː", "d̪ʱ", "d̪ʱː", "e", "eː", "ɛ", "ɛː", "f", "ɡ", "ɡː", "ɡ̤", "ɦ", "i", "iː",
    "j", "jː", "k", "kʰ", "kʰː", "l", "lː", "m", "mː", "n", "nː", "n̪", "n̪ː", "o", "oː", "p", "pʰ", "pʰː", "ɾ", "ɽ",
    "s", "sː", "t̪", "t̪ː", "t̪ʰ", "t̪ʰː", "u", "uː", "ʋ", "z", "ʃ", "ʈ", "ʈʰ", "ʈː", "ɖ", "ɖː", "ɖʱ", "ɖʱː", "ŋ", "ɲ", "ɳ",
    "ə", "ʊ", "ɔ", "ɔː", "ɪ", "ɟ", "ʒ", "ʂ", "æ"
])

# Basic IAST to IPA mapping
iast_to_ipa = {
    "ai": "ɛː", "au": "ɔː",
    "a": "ə", "ā": "aː", "i": "ɪ", "ī": "iː", "u": "ʊ", "ū": "uː",
    "e": "eː", "o": "oː",
    "k": "k", "kh": "kʰ", "g": "ɡ", "gh": "ɡ̤", "ṅ": "ŋ",
    "c": "ʈʃ", "ch": "ʈʃʰ", "j": "ɟ", "jh": "ɟʱ", "ñ": "ɲ",
    "ṭ": "ʈ", "ṭh": "ʈʰ", "ḍ": "ɖ", "ḍh": "ɖʱ", "ṇ": "ɳ",
    "t": "t̪", "th": "t̪ʰ", "d": "d̪", "dh": "d̪ʱ", "n": "n",
    "p": "p", "ph": "pʰ", "b": "b", "bh": "bʱ", "m": "m",
    "y": "j", "r": "ɾ", "l": "l", "v": "ʋ",
    "ś": "ʃ", "ṣ": "ʂ", "s": "s", "h": "ɦ",
    "ṁ": "ŋ", "ḥ": "ɦ"
}

# Convert Devanagari to space-separated IPA phonemes
def convert_to_ipa(dev_text):
    # Devanagari to IAST
    iast = transliterate(dev_text, DEVANAGARI, IAST)

    # Handle multi-letter mappings first
    for key in sorted(iast_to_ipa, key=len, reverse=True):
        iast = iast.replace(key, f" {iast_to_ipa[key]} ")

    # Remove extra spaces
    iast = re.sub(r"\s+", " ", iast).strip()

    # Keep only phonemes in Hindi inventory
    phonemes = [p for p in iast.split() if p in hindi_inventory]

    return " ".join(phonemes)

# Load and clean the file manually
with open("/content/drive/MyDrive/validate.csv", encoding="utf-8") as f:
    lines = f.readlines()

# Clean and parse into a list of (id, transcription)
rows = []
for line in lines[1:]:  # skip header
    parts = line.strip().strip(",").split(",")
    if len(parts) >= 2:
        id_str = parts[0].strip()
        text = ",".join(parts[1:]).strip(" ,\n")
        if id_str.isdigit() and text:
            rows.append((id_str, text))

print(f"✅ Loaded {len(rows)} valid rows.")

# Create DataFrame
df = pd.DataFrame(rows, columns=["ID", "Transcription"])

# Apply conversion
df["IPA_Transcription"] = df["Transcription"].apply(convert_to_ipa)

# Save output
output_path = "/content/drive/MyDrive/validate_IPA.csv"
df[["ID", "IPA_Transcription"]].to_csv(output_path, index=False, sep="\t")
print(f"✅ IPA file saved at {output_path}")
# Out:
# ✅ Loaded 291 valid rows.
# ✅ IPA file saved at /content/drive/MyDrive/validate_IPA.csv

# %% [markdown]
# ## **generating text and wave files:**

# %%
df = pd.read_csv("/content/drive/MyDrive/Dataset/train/train.csv", sep=",", encoding="utf-8")
print("Columns in CSV:", df.columns.tolist())
# Out:
# Columns in CSV: ['ID', 'IPA_Transcription']

# %%
# !pip install allosaurus
# Out:
# Collecting allosaurus
#   Downloading allosaurus-1.0.2-py3-none-any.whl.metadata (400 bytes)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from allosaurus) (1.14.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from allosaurus) (2.0.2)
# Collecting resampy (from allosaurus)
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Collecting panphon (from allosaurus)
#   Downloading panphon-0.21.2-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from allosaurus) (2.6.0+cu124)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.11/dist-packages (from allosaurus) (0.8.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from panphon->allosaurus) (75.2.0)
# Collecting unicodecsv (from panphon->allosaurus)
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from panphon->allosaurus) (6.0.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from panphon->allosaurus) (2024.11.6)
# Collecting munkres (from panphon->allosaurus)
#   Downloading munkres-1.1.4-py2.py3-none-any.whl.metadata (980 bytes)
# Requirement already satisfied: numba>=0.53 in /usr/local/lib/python3.11/dist-packages (from resampy->allosaurus) (0.60.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->allosaurus) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->allosaurus) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->allosaurus) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->allosaurus) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->allosaurus) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->allosaurus)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->allosaurus)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->allosaurus)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->allosaurus)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->allosaurus)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->allosaurus)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->allosaurus)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->allosaurus)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->allosaurus)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->allosaurus) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->allosaurus) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->allosaurus) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->allosaurus)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->allosaurus) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->allosaurus) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->allosaurus) (1.3.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.53->resampy->allosaurus) (0.43.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->allosaurus) (3.0.2)
# Downloading allosaurus-1.0.2-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.7 MB/s eta 0:00:00
# Downloading panphon-0.21.2-py2.py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 8.1 MB/s eta 0:00:00
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 66.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 122.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 98.7 MB/s eta 0:00:00
# Downloading munkres-1.1.4-py2.py3-none-any.whl (7.0 kB)
# Building wheels for collected packages: unicodecsv
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10744 sha256=b8e1fba043413454c73479259a56be131baf656b5e078d1a780931b30a288373
#   Stored in directory: /root/.cache/pip/wheels/ec/03/6f/d2e0162d94c0d451556fa43dd4d5531457245c34a36b41ef4a
# Successfully built unicodecsv
# Installing collected packages: unicodecsv, munkres, panphon, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, resampy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, allosaurus
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed allosaurus-1.0.2 munkres-1.1.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 panphon-0.21.2 resampy-0.4.3 unicodecsv-0.14.1

# %%
# !pip show allosaurus
# Out:
# Name: allosaurus
# Version: 1.0.2
# Summary: a multilingual phone recognizer
# Home-page: https://github.com/xinjli/allosaurus
# Author: Xinjian Li
# Author-email: xinjianl@cs.cmu.edu
# License: UNKNOWN
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: editdistance, numpy, panphon, resampy, scipy, torch
# Required-by:

# %%
# !python -m allosaurus.bin.download_model -m uni2005
# Out:
# downloading model  uni2510
# from:  https://github.com/xinjli/allosaurus/releases/download/v1.0/uni2510.tar.gz
# to:    /usr/local/lib/python3.11/dist-packages/allosaurus/pretrained
# please wait...
# Error: could not download the model
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/allosaurus/bin/download_model.py", line 25, in download_model
#     resp = urlopen(url)
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 216, in urlopen
#     return opener.open(url, data, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 563, in error
#     return self._call_chain(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 643, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404: Not Found
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/allosaurus/bin/download_model.py", line 42, in <module>
#     download_model(args.model)
#   File "/usr/local/lib/python3.11/dist-packages/allosaurus/bin/download_model.py", line 32, in download_model
#     (model_dir / model_name).rmdir()
#   File "/usr/lib/python3.11/pathlib.py", line 1156, in rmdir
#     os.rmdir(self)
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/lib/python3.11/dist-packages/allosaurus/pretrained/uni2510'

# %%
import os
import pandas as pd

def create_data_files(data_dir, split):
    """
    Generates wave and text files from CSV transcription data.

    Args:
    - data_dir (str): Path to the dataset directory.
    - split (str): Either 'train' or 'validate' (subdirectory names).
    """
    audio_dir = os.path.join(data_dir, split, "audio")  # Path to audio folder
    csv_path = os.path.join(data_dir, split, f"{split}.csv")  # CSV file path
    wave_file = os.path.join(data_dir, split, "wave")  # Output wave file
    text_file = os.path.join(data_dir, split, "text")  # Output text file

    # Load the CSV file
    # Try reading as comma-separated
    df = pd.read_csv(csv_path, encoding="utf-8")
    if len(df.columns) == 1 and '\t' in df.columns[0]:
        # Fallback to tab-separated if only one column is detected
        df = pd.read_csv(csv_path, sep='\t', encoding="utf-8")

    # Strip column names and confirm
    df.columns = df.columns.str.strip()
    print(f"Columns after strip in {split}: {df.columns.tolist()}")


    with open(wave_file, "w", encoding="utf-8") as wf, open(text_file, "w", encoding="utf-8") as tf:
        for _, row in df.iterrows():
            utt_id = row["ID"]
            transcription = row["IPA_Transcription"]
            audio_path = os.path.join(audio_dir, f"{utt_id}.wav")

            # Ensure the audio file exists
            if not os.path.exists(audio_path):
                print(f"Warning: Audio file {audio_path} not found. Skipping...")
                continue

            # Write to wave file (mapping utt_id to audio path)
            wf.write(f"{utt_id} {audio_path}\n")

            # Write to text file (mapping utt_id to transcription)
            tf.write(f"{utt_id} {transcription}\n")

    print(f"Successfully created 'wave' and 'text' files in {split}/")

# Define dataset directory
dataset_path = "/content/drive/MyDrive/Dataset"  # Change this to your actual dataset path

# Generate files for train and validate sets
create_data_files(dataset_path, "train")
create_data_files(dataset_path, "validate")
# Out:
# Columns after strip in train: ['ID', 'IPA_Transcription']
# Successfully created 'wave' and 'text' files in train/
# Columns after strip in validate: ['ID', 'IPA_Transcription']
# Successfully created 'wave' and 'text' files in validate/

# %% [markdown]
# EXTRACTING AUDIO FEATURES

# %%
# !python -m allosaurus.bin.prep_feat --model=uni2005 --path=/content/drive/MyDrive/Dataset/validate
# Out:
# 100% 291/291 [00:17<00:00, 16.74it/s]

# %% [markdown]
# EXTRACTING TEXT FEATURES

# %%
# command to prepare token
# !python -m allosaurus.bin.prep_token --model=uni2005 --lang=hin --path=/content/drive/MyDrive/Dataset/train
# Out:
# 100% 1162/1162 [00:00<00:00, 34411.83it/s]

# %%
# command to fine_tune your data
# !python -m allosaurus.bin.adapt_model --pretrained_model=uni2005 --new_model=uni2510 --path="/content/drive/MyDrive/Dataset_allosaurus" --lang=hin --device_id=0 --epoch=20
# Out:
# epoch[batch]: 00[0000] | train loss 5.59926 train per 0.85262
# epoch[batch]: 00[0010] | train loss 4.90026 train per 0.81228
# epoch[batch]: 00[0020] | train loss 4.00996 train per 0.74589
# epoch[batch]: 00[0030] | train loss 3.47739 train per 0.71789
# epoch[batch]: 00[0040] | train loss 3.08052 train per 0.68517
# epoch[batch]: 00[0050] | train loss 2.62968 train per 0.61481
# epoch0 | validate per : 0.59809
# saving model
# epoch[batch]: 01[0000] | train loss 2.46676 train per 0.59928
# epoch[batch]: 01[0010] | train loss 2.42195 train per 0.57673
# epoch[batch]: 01[0020] | train loss 2.30216 train per 0.55101
# epoch[batch]: 01[0030] | train loss 2.16647 train per 0.52643
# epoch[batch]: 01[0040] | train loss 2.06605 train per 0.50643
# epoch[batch]: 01[0050] | train loss 1.95873 train per 0.49510
# epoch1 | validate per : 0.49004
# saving model
# epoch[batch]: 02[0000] | train loss 1.95601 train per 0.50157
# epoch[batch]: 02[0010] | train loss 1.84144 train per 0.47634
# epoch[batch]: 02[0020] | train loss 1.75105 train per 0.46202
# epoch[batch]: 02[0030] | train loss 1.72766 train per 0.46255
# epoch[batch]: 02[0040] | train loss 1.73708 train per 0.46628
# epoch[batch]: 02[0050] | train loss 1.68900 train per 0.45833
# epoch2 | validate per : 0.43821
# saving model
# epoch[batch]: 03[0000] | train loss 1.59985 train per 0.41752
# epoch[batch]: 03[0010] | train loss 1.61106 train per 0.44174
# epoch[batch]: 03[0020] | train loss 1.61031 train per 0.44790
# epoch[batch]: 03[0030] | train loss 1.57343 train per 0.43727
# epoch[batch]: 03[0040] | train loss 1.51124 train per 0.41582
# epoch[batch]: 03[0050] | train loss 1.45162 train per 0.40664
# epoch3 | validate per : 0.43413
# saving model
# epoch[batch]: 04[0000] | train loss 1.51870 train per 0.43648
# epoch[batch]: 04[0010] | train loss 1.43720 train per 0.40664
# epoch[batch]: 04[0020] | train loss 1.42577 train per 0.39513
# epoch[batch]: 04[0030] | train loss 1.35483 train per 0.38333
# epoch[batch]: 04[0040] | train loss 1.47008 train per 0.41769
# epoch[batch]: 04[0050] | train loss 1.41251 train per 0.40595
# epoch4 | validate per : 0.39253
# saving model
# epoch[batch]: 05[0000] | train loss 1.38715 train per 0.38736
# epoch[batch]: 05[0010] | train loss 1.39368 train per 0.39444
# epoch[batch]: 05[0020] | train loss 1.30342 train per 0.36931
# epoch[batch]: 05[0030] | train loss 1.35671 train per 0.39267
# epoch[batch]: 05[0040] | train loss 1.28647 train per 0.36314
# epoch[batch]: 05[0050] | train loss 1.30223 train per 0.36908
# epoch5 | validate per : 0.37658
# saving model
# epoch[batch]: 06[0000] | train loss 1.42505 train per 0.41199
# epoch[batch]: 06[0010] | train loss 1.26396 train per 0.35572
# epoch[batch]: 06[0020] | train loss 1.32378 train per 0.37010
# epoch[batch]: 06[0030] | train loss 1.19756 train per 0.35105
# epoch[batch]: 06[0040] | train loss 1.23337 train per 0.34991
# epoch[batch]: 06[0050] | train loss 1.27464 train per 0.35919
# epoch6 | validate per : 0.39016
# epoch[batch]: 07[0000] | train loss 1.33522 train per 0.39892
# epoch[batch]: 07[0010] | train loss 1.19557 train per 0.33998
# epoch[batch]: 07[0020] | train loss 1.23537 train per 0.34978
# epoch[batch]: 07[0030] | train loss 1.18890 train per 0.33873
# epoch[batch]: 07[0040] | train loss 1.16047 train per 0.33442
# epoch[batch]: 07[0050] | train loss 1.22152 train per 0.34212
# epoch7 | validate per : 0.35696
# saving model
# epoch[batch]: 08[0000] | train loss 1.12355 train per 0.31500
# epoch[batch]: 08[0010] | train loss 1.11212 train per 0.31508
# epoch[batch]: 08[0020] | train loss 1.17490 train per 0.33519
# epoch[batch]: 08[0030] | train loss 1.16519 train per 0.33338
# epoch[batch]: 08[0040] | train loss 1.17389 train per 0.33741
# epoch[batch]: 08[0050] | train loss 1.14676 train per 0.32626
# epoch8 | validate per : 0.34606
# saving model
# epoch[batch]: 09[0000] | train loss 1.04710 train per 0.28947
# epoch[batch]: 09[0010] | train loss 1.17733 train per 0.33079
# epoch[batch]: 09[0020] | train loss 1.06261 train per 0.30800
# epoch[batch]: 09[0030] | train loss 1.05823 train per 0.30798
# epoch[batch]: 09[0040] | train loss 1.13956 train per 0.32429
# epoch[batch]: 09[0050] | train loss 1.11359 train per 0.31491
# epoch9 | validate per : 0.33955
# saving model
# epoch[batch]: 10[0000] | train loss 1.15363 train per 0.31301
# epoch[batch]: 10[0010] | train loss 1.07712 train per 0.30568
# epoch[batch]: 10[0020] | train loss 1.04077 train per 0.29617
# epoch[batch]: 10[0030] | train loss 1.05576 train per 0.30721
# epoch[batch]: 10[0040] | train loss 1.11062 train per 0.31604
# epoch[batch]: 10[0050] | train loss 1.05604 train per 0.29988
# epoch10 | validate per : 0.33297
# saving model
# epoch[batch]: 11[0000] | train loss 0.94560 train per 0.25658
# epoch[batch]: 11[0010] | train loss 1.05865 train per 0.29821
# epoch[batch]: 11[0020] | train loss 1.04801 train per 0.29812
# epoch[batch]: 11[0030] | train loss 1.05401 train per 0.29838
# epoch[batch]: 11[0040] | train loss 1.04315 train per 0.29497
# epoch[batch]: 11[0050] | train loss 0.97712 train per 0.28169
# epoch11 | validate per : 0.32688
# saving model
# epoch[batch]: 12[0000] | train loss 1.03535 train per 0.29054
# epoch[batch]: 12[0010] | train loss 1.04461 train per 0.29658
# epoch[batch]: 12[0020] | train loss 1.04167 train per 0.29532
# epoch[batch]: 12[0030] | train loss 1.00053 train per 0.28370
# epoch[batch]: 12[0040] | train loss 0.95115 train per 0.27009
# epoch[batch]: 12[0050] | train loss 0.96944 train per 0.27303
# epoch12 | validate per : 0.32188
# saving model
# epoch[batch]: 13[0000] | train loss 0.82123 train per 0.23072
# epoch[batch]: 13[0010] | train loss 0.93339 train per 0.26731
# epoch[batch]: 13[0020] | train loss 0.99250 train per 0.28223
# epoch[batch]: 13[0030] | train loss 0.92906 train per 0.26441
# epoch[batch]: 13[0040] | train loss 1.05839 train per 0.29884
# epoch[batch]: 13[0050] | train loss 0.96898 train per 0.26810
# epoch13 | validate per : 0.31464
# saving model
# epoch[batch]: 14[0000] | train loss 0.93173 train per 0.24166
# epoch[batch]: 14[0010] | train loss 0.90109 train per 0.25742
# epoch[batch]: 14[0020] | train loss 0.97106 train per 0.27090
# epoch[batch]: 14[0030] | train loss 0.96669 train per 0.27240
# epoch[batch]: 14[0040] | train loss 0.93889 train per 0.26600
# epoch[batch]: 14[0050] | train loss 0.94169 train per 0.26903
# epoch14 | validate per : 0.31555
# epoch[batch]: 15[0000] | train loss 0.85499 train per 0.23801
# epoch[batch]: 15[0010] | train loss 0.87508 train per 0.24585
# epoch[batch]: 15[0020] | train loss 0.95207 train per 0.27241
# epoch[batch]: 15[0030] | train loss 0.91534 train per 0.25355
# epoch[batch]: 15[0040] | train loss 0.88092 train per 0.24618
# epoch[batch]: 15[0050] | train loss 0.97140 train per 0.27402
# epoch15 | validate per : 0.30946
# saving model
# epoch[batch]: 16[0000] | train loss 0.77754 train per 0.19737
# epoch[batch]: 16[0010] | train loss 0.87464 train per 0.24161
# epoch[batch]: 16[0020] | train loss 0.90704 train per 0.25615
# epoch[batch]: 16[0030] | train loss 0.84942 train per 0.24112
# epoch[batch]: 16[0040] | train loss 0.97416 train per 0.27813
# epoch[batch]: 16[0050] | train loss 0.84988 train per 0.23929
# epoch16 | validate per : 0.31110
# epoch[batch]: 17[0000] | train loss 0.79276 train per 0.25068
# epoch[batch]: 17[0010] | train loss 0.80368 train per 0.22854
# epoch[batch]: 17[0020] | train loss 0.84701 train per 0.22803
# epoch[batch]: 17[0030] | train loss 0.99647 train per 0.27954
# epoch[batch]: 17[0040] | train loss 0.87416 train per 0.24614
# epoch[batch]: 17[0050] | train loss 0.83311 train per 0.23558
# epoch17 | validate per : 0.30501
# saving model
# epoch[batch]: 18[0000] | train loss 0.78373 train per 0.21505
# epoch[batch]: 18[0010] | train loss 0.77942 train per 0.21472
# epoch[batch]: 18[0020] | train loss 0.79505 train per 0.22134
# epoch[batch]: 18[0030] | train loss 0.93361 train per 0.25920
# epoch[batch]: 18[0040] | train loss 0.82826 train per 0.22933
# epoch[batch]: 18[0050] | train loss 0.88830 train per 0.25018
# epoch18 | validate per : 0.30471
# saving model
# epoch[batch]: 19[0000] | train loss 0.75240 train per 0.21361
# epoch[batch]: 19[0010] | train loss 0.79265 train per 0.22395
# epoch[batch]: 19[0020] | train loss 0.86477 train per 0.23707
# epoch[batch]: 19[0030] | train loss 0.82790 train per 0.23019
# epoch[batch]: 19[0040] | train loss 0.80113 train per 0.22169
# epoch[batch]: 19[0050] | train loss 0.82643 train per 0.23360
# epoch19 | validate per : 0.30044
# saving model

# %%
# !find / -type d -name "uni2510" 2>/dev/null
# Out:
# /usr/local/lib/python3.11/dist-packages/allosaurus/pretrained/uni2510

# %%
# !cp -r /usr/local/lib/python3.11/dist-packages/allosaurus/pretrained/uni2510 /content/drive/MyDrive/uni2510

# %%
# command to check all your models
# !python -m allosaurus.bin.list_model
# Out:
# Available Models
# - uni2510 (default)
# - uni2005

# %%
# !python -m allosaurus.run --lang hin --model uni2510 --device_id 0 -i "/content/drive/MyDrive/Dataset_allosaurus/validate/audio/281474976714320.wav"
# Out:
# m eː s ə d̪ ə d̪ ʊ eː ɛː ɾ ə eː ɛː

# %% [markdown]
# ROUGH

# %%
import os
import subprocess
import csv

# Set your parameters
input_directory = "/content/drive/MyDrive/Dataset_allosaurus/validate/audio"
lang = "hin"
model = "uni2510"
device_id = "0"

# Output CSV file path
output_csv = "/content/drive/MyDrive/Dataset_allosaurus/validate/transcriptions.csv"

# Make a list of all WAV files
wav_files = [f for f in os.listdir(input_directory) if f.endswith(".wav")]
total_files = len(wav_files)

print(f"Found {total_files} WAV files.\n")

# Create a new CSV file and write the header
with open(output_csv, mode='w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["ID", "Transcription"])  # Write header

    # Process each file
    for idx, filename in enumerate(wav_files, start=1):
        filepath = os.path.join(input_directory, filename)

        # Build the command
        command = [
            "python", "-m", "allosaurus.run",
            "--lang", lang,
            "--model", model,
            "--device_id", device_id,
            "-i", filepath
        ]

        # Run Allosaurus and capture output
        result = subprocess.run(command, capture_output=True, text=True)
        transcription = result.stdout.strip()

        # Write ID and transcription to CSV immediately
        writer.writerow([filename, transcription])

        # Print progress and transcription
        print(f"[{idx}/{total_files}] Processed: {filename}")
        print("Transcription:")
        print(transcription)
        print("-" * 50)

print(f"\n✅ All transcriptions saved to: {output_csv}")
# Out:
# Found 299 WAV files.
#
# [1/299] Processed: 281474976735665.wav
# Transcription:
# b ə aː k ɔː n aː m ə p ə ɖ d̪ ə ɟ iː d̪ t̪ eː ɛː aː ə b ə n ə b ɡ ɛː ɾ aː ɦ ɔː k oː t̪ ʊ eː ɛː k oː n ə l iː ɡ ʊ n d̪ ə l iː p ə t̪ ʊ aː b ə k ɪ ɾ aː d̪ eː k eː b ə aː k ə n aː m ə t̪ ə p ɔː ɟ aː t̪ ʊ eː ɛː
# --------------------------------------------------
# [2/299] Processed: 281474976735664.wav
# Transcription:
# n aː m ɔː ɾ ə k ɪ ə m k ɪ k aː ɾ ɪ k ɾ ə m ə m ɪ ɾ ɔː l iː m ɔː l iː aː b ə l ɟ ə n uː ɡ ɔː b ʊ l aː l ə aː d̪ ɪ k aː p iː oː k iː aː ɟ aː t̪ ʊ eː ɛː
# --------------------------------------------------
# [3/299] Processed: 281474976735659.wav
# Transcription:
# b ə p ɛː d̪ ə ɦ ɔː n eː k ɪ b aː ɾ ɪ t̪ iː k iː ɟ aː t̪ eː ɛː s ə m ɪ d̪ aː b ə t̪ ə k iː t̪ ɪ p ɪ ɟ ə s ə m ɛː k eː ɟ ɪ t̪ n eː b iː l oː ɡ oː t̪ ə ɟ eː s ɪ p ə s ʊ ɟ ɪ s k eː b aː ə ɟ ɪ t̪ ə n aː ə p ɛː s aː b ʊ s ə k j ə aː n ə s aː ɾ ə ɦ oː l oː ɡ ə b aː b ə t̪ ə k ə ɾ ə p eː ɔː ɾ ə l oː ɡ uː k ə n ɪ m ə n t̪ ə ɾ ɪ s k ə ɾ k eː aː b ə t̪ ə k aː b aː t̪ ə eː ɛː
# --------------------------------------------------
# [4/299] Processed: 281474976735663.wav
# Transcription:
# n aː ə t̪ ə ɾ ɪ b eː k ɪ n ɛː s uː t̪ ɪ k aː k ʊ s d̪ iː k ə ɖ ə k p ə n ɔː k ə ɾ aː ɪ k ɪ t̪ ɪ ɾ ə b aː k eː b aː d̪ ɪ m n aː b ə ɾ ə k ɔː ɟ aː t̪ ʊ eː ɛː
# --------------------------------------------------
# [5/299] Processed: 281474976714381.wav
# Transcription:
# m ɛː k ə d̪ ə k uː b ə s ə n ə k ə t̪ uː ə b ʊ k ɔː ɾ ə uː k uː p ə n ə n ə k ə t̪ ɪ eː ɛː
# --------------------------------------------------
# [6/299] Processed: 281474976714372.wav
# Transcription:
# m ɪ t̪ eː ɟ ɪ b ə ɦ aː ɡ ə
# --------------------------------------------------
# [7/299] Processed: 281474976714361.wav
# Transcription:
# m ɛː n ɪ b aː t̪ ɪ k ɔː ʊ t̪ ʊ ɾ ə b aː oː
# --------------------------------------------------
# [8/299] Processed: 281474976714362.wav
# Transcription:
# m n ɪ k aː m ə m aː iː b ɪ ɾ iː aː p ɪ k ə b ə ɾ aː p ə k ə ɾ ə b aː
# --------------------------------------------------
# [9/299] Processed: 281474976714369.wav
# Transcription:
# b ʊ b aː eː k ɪ t̪ aː b ə d̪ ɛː ɾ ə oː
# --------------------------------------------------
# [10/299] Processed: 281474976714365.wav
# Transcription:
# m eː b aː eː ɛː ɾ oː s ə k ɪ t̪ aː b ə d̪ eː t̪ ʊ
# --------------------------------------------------
# [11/299] Processed: 281474976714341.wav
# Transcription:
# p iː t̪ aː ɾ ə k uː ɔː ɾ ə aː ɟ aː k uː l ə aː ɡ ɔː k ə b eː ɾ iː b oː d̪ uː s ə ɾ ə eː ɛː t̪ eː l ə ɖ ə ɾ ə aː ɛː
# --------------------------------------------------
# [12/299] Processed: 281474976714347.wav
# Transcription:
# k aː ɟ ɪ k s ə ɾ ə iː ɦ aː t̪ ʊ m aː ɪ l ə eː ɛː
# --------------------------------------------------
# [13/299] Processed: 281474976714335.wav
# Transcription:
# t̪ iː t̪ uː k ɪ m aː n eː t̪ iː ʈʰ uː s eː ɾ aː d̪ aː k uː s ʊ l ə b aː ɔː
# --------------------------------------------------
# [14/299] Processed: 281474976714332.wav
# Transcription:
# b ʊ p ʊ t̪ ɔː ə l ə ɾ oː ɟ ə k n t̪ ʊ eː ɛː
# --------------------------------------------------
# [15/299] Processed: 281474976714324.wav
# Transcription:
# b ʊ ɡ ə ɾ ə aː m ɪ ɦ aː t̪ ʊ
# --------------------------------------------------
# [16/299] Processed: 281474976714326.wav
# Transcription:
# t̪ aː ɟ ʊ n ɪ ɡ̤ ə ɾ ə oː d̪ ɔː
# --------------------------------------------------
# [17/299] Processed: 281474976714322.wav
# Transcription:
# t̪ ʊ m ə aː b ə n aː eː ɪ ɟ aː ɪ s ə k ɪ ɡ eː
# --------------------------------------------------
# [18/299] Processed: 281474976714320.wav
# Transcription:
# m eː s ə d̪ ə d̪ ʊ eː ɛː ɾ ə eː ɛː
# --------------------------------------------------
# [19/299] Processed: 281474976730198.wav
# Transcription:
# m ɛː ɪ n ə iː k aː ɾ ɔː oː uː ɡ ɔː
# --------------------------------------------------
# [20/299] Processed: 281474976730199.wav
# Transcription:
# k aː ɾ aː ɾ ɪ d̪ ɛː k ɪ s ə ɾ aː b ɛː m ə n d̪ ɪ ɾ ə p ə ɟ ɪ ə ɾ ə eː p aː d̪ ə n iː p ɛː ɟ aː ɾ ə l ə eː ɛː
# --------------------------------------------------
# [21/299] Processed: 281474976730212.wav
# Transcription:
# ɟ iː d̪ oː k eː m aː n eː t̪ iː t̪ ʊ ə eː ɾ aː ɾ ə s ə p ə p aː iː
# --------------------------------------------------
# [22/299] Processed: 281474976730213.wav
# Transcription:
# ɦ ə m ə k uː b iː ɟ aː s ə k ə t̪ ə eː ɛː
# --------------------------------------------------
# [23/299] Processed: 281474976730205.wav
# Transcription:
# m aː ə ɟ ə b aː t̪ ə s ɛː ɾ ə ɟ aː m n ɪ k aː t̪ ə oː
# --------------------------------------------------
# [24/299] Processed: 281474976730175.wav
# Transcription:
# b ʊ ɡ aː ɪ ə n aː s ə k ə t̪ oː
# --------------------------------------------------
# [25/299] Processed: 281474976730172.wav
# Transcription:
# m ɛː k ɔː d̪ ɛː ə p ə s ə l ə k ə t̪ uː b ʊ k ʊ t̪ ə ɛː k p s ə m ɪ k ə t̪ ə t̪ ɪ eː aː ɛː
# --------------------------------------------------
# [26/299] Processed: 281474976730176.wav
# Transcription:
# m ɛː b aː s ɪ aː m ə l ɪ k aː t̪ ʊ
# --------------------------------------------------
# [27/299] Processed: 281474976730165.wav
# Transcription:
# m ɛː ɔː m eː b ə ɟ aː ɡ ə k ɪ l ə ɡ eː
# --------------------------------------------------
# [28/299] Processed: 281474976730170.wav
# Transcription:
# k aː t̪ ə m k ə l ɪ ɟ aː ɦ aː s ə k ə t̪ ʊ ɔː
# --------------------------------------------------
# [29/299] Processed: 281474976730168.wav
# Transcription:
# d̪ ə m aː ɛː ɟ aː oː
# --------------------------------------------------
# [30/299] Processed: 281474976730164.wav
# Transcription:
# b ʊ k ə l ɪ k ə k ə l ə k ə l t̪ aː ɟ aː ɪ j ɾ ɔː eː ɛː
# --------------------------------------------------
# [31/299] Processed: 281474976730159.wav
# Transcription:
# b ʊ d̪ ə ɾ aː m ə t̪ ɪ ɡ eː ɾ ə ɡ ɔː
# --------------------------------------------------
# [32/299] Processed: 281474976730160.wav
# Transcription:
# m ɛː k ə eː ɪ s ʊ l ə n ɪ aː ɡ oː
# --------------------------------------------------
# [33/299] Processed: 281474976730161.wav
# Transcription:
# b ʊ p ə t̪ ʊ b aː ɾ ə ɾ oː ɟ iː n aː k eː l ə t̪ ʊ eː ɛː
# --------------------------------------------------
# [34/299] Processed: 281474976730148.wav
# Transcription:
# m eː aː s ə b aː d̪ ə m ʊ s b ə b ɔː t̪ ə b ə ɖ ə aː eː ɛː
# --------------------------------------------------
# [35/299] Processed: 281474976730143.wav
# Transcription:
# p t̪ aː ɟ ə n ə b ə n ə k l ə k ə l ɔː n aː ə k iː t̪ ə eː ɛː
# --------------------------------------------------
# [36/299] Processed: 281474976730149.wav
# Transcription:
# ɦ ə m ə n t̪ eː m ɪ n aː b ʊ ɟ aː k ʊ s iː ɟ ə m ə t̪ ɪ eː
# --------------------------------------------------
# [37/299] Processed: 281474976730146.wav
# Transcription:
# p uː l ə k ɛː
# --------------------------------------------------
# [38/299] Processed: 281474976730144.wav
# Transcription:
# s ə m ə n ə s ə b eː ɾ ɪ aː m ə l ɔː n aː iː
# --------------------------------------------------
# [39/299] Processed: 281474976730129.wav
# Transcription:
# m eː b ɛː ɾ ə b ɪ ə ɟ aː l ə m ɛː
# --------------------------------------------------
# [40/299] Processed: 281474976730130.wav
# Transcription:
# ɾ aː d̪ aː ɾ ə k t̪ ə ɾ ə p ə iː t̪ aː m ɪ l oː ɡ
# --------------------------------------------------
# [41/299] Processed: 281474976730132.wav
# Transcription:
# ɟ ɪ d̪ ʊ eː ɛː ɡ aː d̪ aː ɛː ɪ s ʊ aː ɔː
# --------------------------------------------------
# [42/299] Processed: 281474976730127.wav
# Transcription:
# b ɪ l ə l oː b ə n ɛː ə p ə l ɔː k aː m ə n ə k ə t̪ ə m ə ɡ ə ɾ ə ɔː
# --------------------------------------------------
# [43/299] Processed: 281474976730134.wav
# Transcription:
# b eː ə k ə ɾ eː ɟ iː ɦ oː l ə t̪ ə eː ɛː
# --------------------------------------------------
# [44/299] Processed: 281474976730106.wav
# Transcription:
# m iː aː l ɔː k ə d̪ ɛː ɾ ə oː eː ɛː
# --------------------------------------------------
# [45/299] Processed: 281474976730114.wav
# Transcription:
# ɪ ɾ iː aː ə b t̪ eː ɾ ə p ə l aː eː
# --------------------------------------------------
# [46/299] Processed: 281474976730104.wav
# Transcription:
# ɟ aː ɾ uː k ɾ ə m oː
# --------------------------------------------------
# [47/299] Processed: 281474976730092.wav
# Transcription:
# b ʊ ɾ oː ɟ ə s ə k uː l ə ɟ aː t̪ ɔː
# --------------------------------------------------
# [48/299] Processed: 281474976730086.wav
# Transcription:
# b ʊ b ə l ɛː k ə l ə t̪ ʊ eː ɛː
# --------------------------------------------------
# [49/299] Processed: 281474976730073.wav
# Transcription:
# ə b ə n ɔː k aː n ɔː k aː ɪ b eː k aː t̪ ʊ ɪ s ʊ eː ə l ə ɔː ɡ ɔː
# --------------------------------------------------
# [50/299] Processed: 281474976730078.wav
# Transcription:
# p ə t̪ aː s ə k uː l ə ɟ aː ɪ ɾ ə ɔː eː ɛː
# --------------------------------------------------
# [51/299] Processed: 281474976730061.wav
# Transcription:
# k ə l eː d̪ ə s t̪ ʊ ɾ ə b ə ɟ eː s ə b eː iː ɾ ɛː b ʊ ɟ aː ɔː ɡ ɔː
# --------------------------------------------------
# [52/299] Processed: 281474976730079.wav
# Transcription:
# k ɔː n ə k ʊ s k iː p ə ɾ ə s ɪ n aː k ə t̪ ʊ ɡ ə t̪ ɪ ɛː ɟ oː k ʊ d̪ ə k iː p ə ɾ ə s n s aː k ə t̪ ʊ b ə t̪ ɪ eː ɛː
# --------------------------------------------------
# [53/299] Processed: 281474976730074.wav
# Transcription:
# ɾ ə m ə n ɛː p ə ɾ ə t̪ eː ɡ̤ ə ɾ ə b ə n aː b eː ɛː
# --------------------------------------------------
# [54/299] Processed: 281474976730053.wav
# Transcription:
# k ʊ t̪ ɪ b ə ɦ ʊ k ə ɾ ə eː ɛː
# --------------------------------------------------
# [55/299] Processed: 281474976730070.wav
# Transcription:
# b ʊ ə ɟ ə ɡ ə ɡ ə l ə m eː ɛː
# --------------------------------------------------
# [56/299] Processed: 281474976730045.wav
# Transcription:
# b aː n ə d̪ eː ɛː k ɔː k b eː ɟ ə n iː p ə t̪ ə ɾ ə t̪ eː k ɪ l ə eː ɛː
# --------------------------------------------------
# [57/299] Processed: 281474976730067.wav
# Transcription:
# ə ɾ ə ɟ ə n eː ɛː d̪ ə s ə ɾ ə b ɪ aː d̪ eː oː
# --------------------------------------------------
# [58/299] Processed: 281474976730038.wav
# Transcription:
# n aː ɔː b oː t̪ aː eː ɛː
# --------------------------------------------------
# [59/299] Processed: 281474976729951.wav
# Transcription:
# t̪ ʊ m ə b ə s ə n ə m ə m ə ɾ ə p ɛː s ɛː ə t̪ eː k ə s ə b aː ɟ aː ɪ s ə b aː t̪ ɔː
# --------------------------------------------------
# [60/299] Processed: 281474976729960.wav
# Transcription:
# s iː t̪ eː aː b ɔː ɾ ə aː ɟ ə eː ɪ l ə ɡ ɔː k ɪ b eː k ə d̪ uː s ə ɾ eː iː k eː ɾ ə l ə ɾ ə ɡ eː ɛː
# --------------------------------------------------
# [61/299] Processed: 281474976730018.wav
# Transcription:
# ɾ aː ɟ aː n ɛː b ə n ə ɡ̤ ə ɾ ə k ə l eː iː oː d̪ oː
# --------------------------------------------------
# [62/299] Processed: 281474976729963.wav
# Transcription:
# m ɛː aː m ə n ə n ə b ə s ə b ə ɟ iː k aː ɪ ɾ uː
# --------------------------------------------------
# [63/299] Processed: 281474976729962.wav
# Transcription:
# k ə l ɪ b n aː ʊ t̪ aː k ɔː k ə l ə l oː ɡ
# --------------------------------------------------
# [64/299] Processed: 281474976729947.wav
# Transcription:
# ə ɡ ə ɾ ə m iː ɦ ɾ ə ɔː ɦ oː t̪ ɔː k eː t̪ ə l ə iː ɔː ɡ iː
# --------------------------------------------------
# [65/299] Processed: 281474976729931.wav
# Transcription:
# b eː ɟ oː ɡ ə n ə ɾ ə s iː n ə t̪ ɪ b aː n ə d̪ ə
# --------------------------------------------------
# [66/299] Processed: 281474976729930.wav
# Transcription:
# ɾ aː d̪ ə aː m ɪ ɛː p ə d̪ ə ɾ eː k eː l eː ɡ ə d̪ aː ɾ ə k ə iː t̪ ə iː
# --------------------------------------------------
# [67/299] Processed: 281474976729927.wav
# Transcription:
# k aː ɟ ɪ s iː ɾ ə ɛː b ɔː t̪ ʊ aː ɪ d̪ eː l ə eː ɛː
# --------------------------------------------------
# [68/299] Processed: 281474976729989.wav
# Transcription:
# t̪ ʊ m eː ɦ aː ə b ə n eː ə n ɔː ə ʊ ɟ eː ɛː
# --------------------------------------------------
# [69/299] Processed: 281474976729990.wav
# Transcription:
# ɦ ə l ə m eː b ə p ə ɾ ɛː ɡ ɔː
# --------------------------------------------------
# [70/299] Processed: 281474976729992.wav
# Transcription:
# b oː ʊ l ɪ s ə l ə k ɛː b ə n ə k ə ɾ ə p aː ɟ ə ɔː
# --------------------------------------------------
# [71/299] Processed: 281474976729919.wav
# Transcription:
# m ɛː b aː t̪ ɪ n aː m ɪ l t̪ oː
# --------------------------------------------------
# [72/299] Processed: 281474976729925.wav
# Transcription:
# b aː n ɛː d̪ ə oː ɟ ə n aː ə p ɛː l ə ɛː b ə b ɔː b ə s ə k uː l ɔː d̪ ə t̪ ʊ
# --------------------------------------------------
# [73/299] Processed: 281474976730001.wav
# Transcription:
# b ə ɔː s aː n t̪ iː ə s ʊ eː ɾ ɔː eː ɛː
# --------------------------------------------------
# [74/299] Processed: 281474976729926.wav
# Transcription:
# m ə ɪ d̪ ʊ ɾ eː ɛː ɡ̤ ə ɾ ə b ə t̪ aː ɪ b eː k eː l ə b ə p ə ʈʰ aː d̪ ə s ə t̪ ə ɾ iː k iː d̪ ə ɾ ə b oː t̪ ə eː ɛː
# --------------------------------------------------
# [75/299] Processed: 281474976729976.wav
# Transcription:
# k aː ɪ ɾ b ə ɡ aː ə s ɔː iː ɔː
# --------------------------------------------------
# [76/299] Processed: 281474976729900.wav
# Transcription:
# m ɛː k ɪ ɾ ə k oː ə b ɟ eː k aː ə n ə b ʊ t̪ ə k ə k ə ɾ ə m aː b iː
# --------------------------------------------------
# [77/299] Processed: 281474976729892.wav
# Transcription:
# ə ɡ ə ɾ ə m eː ɦ ʊ k ə ɾ ɛː ə b ɔː t̪ ɔː m ɪ k ɪ n ə ɔː n aː m ə ɡ ɔː
# --------------------------------------------------
# [78/299] Processed: 281474976729899.wav
# Transcription:
# k ə l ə ɟ aː s ə m ɛː t̪ ə k ə b ʊ k ə l ə k ə t̪ ə t̪ ɔː p ɔː ɪ l ɪ ɔː ɡ iː
# --------------------------------------------------
# [79/299] Processed: 281474976729961.wav
# Transcription:
# b eː ɟ aː n aː t̪ ʊ eː ɛː
# --------------------------------------------------
# [80/299] Processed: 281474976729861.wav
# Transcription:
# s uː ɾ ə ɪ p uː ɾ ə m ə m ə ɦ ə t̪ ʊ eː ɛː
# --------------------------------------------------
# [81/299] Processed: 281474976729872.wav
# Transcription:
# m eː p ə ɾ ɪ b aː ɾ ə k eː ɟ b ə ɾ ə eː ɛː m ə ɾ ʊ k aː ɾ ə m ə ɾ ə k iː eː ɛː
# --------------------------------------------------
# [82/299] Processed: 281474976729853.wav
# Transcription:
# b ʊ ə b ə ɡ̤ ə ɾ ə p ɛː ɦ oː ɡ oː
# --------------------------------------------------
# [83/299] Processed: 281474976727226.wav
# Transcription:
# s ə ɾ aː d̪ aː eː ɪ m ə ɡ t̪ eː ɟ ɪ n ə iː aː ɪ
# --------------------------------------------------
# [84/299] Processed: 281474976727219.wav
# Transcription:
# m eː ə m aː n ɪ m ɪ b ɔː ə s aː ɪ k ə s ə k ʊ l ə d̪ ə eː ɟ ə t̪ eː
# --------------------------------------------------
# [85/299] Processed: 281474976727228.wav
# Transcription:
# n iː eː t̪ ə eː ɛː ʊ ɡ̤ aː ɾ ə m ɪ b ɪ s t̪ aː ɾ ə b ə t̪ aː ɔː b aː eː
# --------------------------------------------------
# [86/299] Processed: 281474976727220.wav
# Transcription:
# k ʊ t̪ aː n ɪ b ə ɾ ə l aː ɪ d̪ ə ɔː
# --------------------------------------------------
# [87/299] Processed: 281474976727222.wav
# Transcription:
# k ə b ə m ə k aː ɪ l ə
# --------------------------------------------------
# [88/299] Processed: 281474976727221.wav
# Transcription:
# ə ɡ ə ɾ ə b uː k ə l aː ɟ aː t̪ ʊ oː t̪ uː ə t̪ ʊ aː ɾ ə m ə n aː ɪ l eː t̪ eː
# --------------------------------------------------
# [89/299] Processed: 281474976727215.wav
# Transcription:
# ɦ ə m ə ɡ eː ə m ə b ə eː k ə b eː iː l aː m ɪ ɟ aː ɪ ɾ ə eː ɛː
# --------------------------------------------------
# [90/299] Processed: 281474976727201.wav
# Transcription:
# p ə b ə ɦ oː ɟ iː m iː k ə b aː t̪ ɪ eː ɛː
# --------------------------------------------------
# [91/299] Processed: 281474976727197.wav
# Transcription:
# t̪ ʊ m aː ɔː k aː n aː m ə eː ɛː
# --------------------------------------------------
# [92/299] Processed: 281474976727184.wav
# Transcription:
# m eː ɛː ɾ ə ɟ aː ɾ ə n k ə ɾ ə k ə t̪ aː ɟ aː ɡ oː
# --------------------------------------------------
# [93/299] Processed: 281474976727176.wav
# Transcription:
# m ɛː n ɪ oː ɾ iː t̪ iː k ə m ə ɾ aː s aː b k ə ɾ ə b aː ɔː
# --------------------------------------------------
# [94/299] Processed: 281474976727157.wav
# Transcription:
# b uː ʊ ɾ oː k ə l iː ɟ ə b ə ɛː ɾ ə ɛː ɪ p ɔː m ɔː ə k ɔː
# --------------------------------------------------
# [95/299] Processed: 281474976727169.wav
# Transcription:
# p ɾ ə p ɛː b ə n d̪ ə ɾ ə eː ɛː
# --------------------------------------------------
# [96/299] Processed: 281474976727142.wav
# Transcription:
# b ʊ k ə l ə k ə t̪ aː t̪ ɪ aː ɡ eː ɔː
# --------------------------------------------------
# [97/299] Processed: 281474976727150.wav
# Transcription:
# t̪ ʊ m ɾ aː t̪ uː m ɟ aː ɔː ə l ə k aː eː ɛː
# --------------------------------------------------
# [98/299] Processed: 281474976727148.wav
# Transcription:
# ɡ uː ɪ s k uː l ə ɟ aː ɾ ɔː b eː ɛː
# --------------------------------------------------
# [99/299] Processed: 281474976727163.wav
# Transcription:
# ɦ ə m ə t̪ ɪ b ɪ n aː m p uː ɛː n ə d̪ ə ɾ ə m ə t̪ ɪ eː aː ɔː
# --------------------------------------------------
# [100/299] Processed: 281474976727152.wav
# Transcription:
# k uː l ə t̪ ʊ s ə n ə d̪ ə ɾ eː ɛː
# --------------------------------------------------
# [101/299] Processed: 281474976727129.wav
# Transcription:
# k ə iː oː ɾ aː k ə l aː s ə m ɛː ɡ aː eː
# --------------------------------------------------
# [102/299] Processed: 281474976727135.wav
# Transcription:
# t̪ ʊ m ə n eː ɪ b aː k ɪ t̪ aː b ə d̪ ə iː
# --------------------------------------------------
# [103/299] Processed: 281474976727141.wav
# Transcription:
# b uː aː b ə ɛː t̪ ɔː k aː ɦ oː ə l ɔː ɡ ə
# --------------------------------------------------
# [104/299] Processed: 281474976727121.wav
# Transcription:
# s aː l ɡ k ɔː ɾ ə s ə m aː n ə ɾ ə k iː ɟ aː ə k ə ɾ ɔː ə k ɪ n t̪ ɔː ɡ ə ɾ ɪ aː s ɪ ɾ ɪ eː ɟ aː t̪ iː
# --------------------------------------------------
# [105/299] Processed: 281474976727122.wav
# Transcription:
# b aː ɾ ə k ɔː n aː m ə k ɪ s n aː eː ɛː
# --------------------------------------------------
# [106/299] Processed: 281474976727105.wav
# Transcription:
# m eː s ə ɾ ə m ə n aː ɾ ə d̪ ə eː ɛː ɪ ɾ ə oː eː ɛː
# --------------------------------------------------
# [107/299] Processed: 281474976727114.wav
# Transcription:
# b eː k ɔː n eː
# --------------------------------------------------
# [108/299] Processed: 281474976727112.wav
# Transcription:
# m ɛː s ə l n aː b aː ɪ ɾ ə ɔː
# --------------------------------------------------
# [109/299] Processed: 281474976727084.wav
# Transcription:
# b ɪ n ɪ ɦ ə m eː aː s iː ɾ ə aː d̪ ə d̪ ə oː
# --------------------------------------------------
# [110/299] Processed: 281474976727089.wav
# Transcription:
# m n ə k ə l ɪ n ə iː k aː
# --------------------------------------------------
# [111/299] Processed: 281474976727082.wav
# Transcription:
# m iː ɟ eː k ɪ t̪ ə d̪ ə ɟ ə n ɪ k eː ə ɾ aː ə d̪ ɛː d̪ ɔː
# --------------------------------------------------
# [112/299] Processed: 281474976727078.wav
# Transcription:
# b eː ɟ aː p ə ɛː n aː ɪ
# --------------------------------------------------
# [113/299] Processed: 281474976727093.wav
# Transcription:
# k ə l d̪ ə s ɔː oː ɟ eː s ʊ b ə ɛː ɟ aː p ə aː ɟ ə t̪ ʊ m ə
# --------------------------------------------------
# [114/299] Processed: 281474976727062.wav
# Transcription:
# aː ɪ p iː l ə
# --------------------------------------------------
# [115/299] Processed: 281474976727068.wav
# Transcription:
# k oː ɾ ə n m ɪ ə ɡ̤ ə ɾ ə k oː ɟ ɡ aː ə ɟ ə ɾ aː ɪ d̪ ə ɔː
# --------------------------------------------------
# [116/299] Processed: 281474976727083.wav
# Transcription:
# b aː n ɪ d̪ oː d̪ ɪ n aː p ɛː l ɪ b ə k ə s aː k ɔː l ə ɔː ɡ oː
# --------------------------------------------------
# [117/299] Processed: 281474976727080.wav
# Transcription:
# b ʊ ɾ ə m ə m ɛː d̪ aː n ə ɟ aː ɪ ɾ ə ɔː eː ɛː
# --------------------------------------------------
# [118/299] Processed: 281474976727047.wav
# Transcription:
# t̪ ʊ m ə b ə ɟ aː ə ɟ aː ɪ ɾ ə ɔː
# --------------------------------------------------
# [119/299] Processed: 281474976727053.wav
# Transcription:
# m eː p aː s ə p ə iː s ə n aː ɪ
# --------------------------------------------------
# [120/299] Processed: 281474976727050.wav
# Transcription:
# m ɔː eː ɪ b oː ɡ ə n aː eː
# --------------------------------------------------
# [121/299] Processed: 281474976727052.wav
# Transcription:
# b ʊ ə m ə ɾ ə ɟ iː b oː l ə t̪ ʊ eː ɛː
# --------------------------------------------------
# [122/299] Processed: 281474976727051.wav
# Transcription:
# t̪ ɪ k uː k iː m aː n ɪ ɟ iː uː p uː ɾ aː d̪ aː t̪ ɪ s ɪ l b aː b ə t̪ ʊ
# --------------------------------------------------
# [123/299] Processed: 281474976727043.wav
# Transcription:
# k ə b t̪ eː ɟ ə l ɛː k aː t̪ ə oː
# --------------------------------------------------
# [124/299] Processed: 281474976727063.wav
# Transcription:
# m ɛː n eː b aː k eː b ə iː ə d̪ k ə
# --------------------------------------------------
# [125/299] Processed: 281474976727034.wav
# Transcription:
# ɡ aː m ə k ɔː ɟ iː s ə b ə n t̪ ɪ p ɾ aː n aː p eː ɾ ə eː ɛː
# --------------------------------------------------
# [126/299] Processed: 281474976727039.wav
# Transcription:
# k ə m ə d̪ ɔː aː m aː eː k ɾ uː ɪ s ɟ ɪ t̪ ə m ɪ l eː ɦ ə t̪ ə eː
# --------------------------------------------------
# [127/299] Processed: 281474976727009.wav
# Transcription:
# m ɛː n ɪ b aː ə k ə b ə aː d̪ ə ɔː
# --------------------------------------------------
# [128/299] Processed: 281474976727018.wav
# Transcription:
# ɾ aː d̪ aː ə m ə m eː s ə k ɪ s ɪ ə b ɔː ɟ aː ɾ ɪ ɡ ə eː iː
# --------------------------------------------------
# [129/299] Processed: 281474976727002.wav
# Transcription:
# ə ɾ ɟ iː s ɪ n ɪ ɡ ə ɾ ə oː ɾ ə t̪ ə ɔː
# --------------------------------------------------
# [130/299] Processed: 281474976726996.wav
# Transcription:
# m eː p aː s ə p ə iː s aː n iː ɦ oː t̪ ɪ t̪ ɔː m ɪ ɛː n ə l ə s ə k ə t̪ ʊ
# --------------------------------------------------
# [131/299] Processed: 281474976726977.wav
# Transcription:
# m ɾ d̪ ɪ n ə ɟ ə l ə t̪ ɪ ə l ə t̪ ə k ə aː t̪ uː
# --------------------------------------------------
# [132/299] Processed: 281474976726993.wav
# Transcription:
# ɔː ɾ ə ɡ ə ɟ eː ɛː n ə m ə ɡ oː s ɔː b ə n ɪ s ə n ə d̪ ə ɾ eː ɛː
# --------------------------------------------------
# [133/299] Processed: 281474976727000.wav
# Transcription:
# m ɛː n ə oː iː t̪ ɪ b oː ɖ ɪ ə k iː k ɪ k aː m ə b aː l iː p ə k ə aː s aː t̪ ə p ə ɾ ə b aː l iː oː
# --------------------------------------------------
# [134/299] Processed: 281474976726981.wav
# Transcription:
# p ə n l ə n aː ɔː
# --------------------------------------------------
# [135/299] Processed: 281474976726997.wav
# Transcription:
# b ɾ ɛː k ə l ɪ n ə ɡ aː ɾ ə ɡ ə b ə t̪ ʊ
# --------------------------------------------------
# [136/299] Processed: 281474976726986.wav
# Transcription:
# b eː ə m aː eː s ə m ə p ə aː ɪ k eː b ʊ k iː aː eː ɛː
# --------------------------------------------------
# [137/299] Processed: 281474976726965.wav
# Transcription:
# ɟ aː ɡ ɔː l ə p k ɪ b eː ɛː ɾ ə ɪ p ə l ɛː k ɪ aː
# --------------------------------------------------
# [138/299] Processed: 281474976726976.wav
# Transcription:
# ɾ aː d̪ aː ɡ eː ɛː p ə l eː iː s aː ɾ iː k ə d̪ iː d̪ iː t̪
# --------------------------------------------------
# [139/299] Processed: 281474976726957.wav
# Transcription:
# b ɾ ɪ b eː ɾ ə b aː ɪ b ɦ oː d̪ ə d̪ ɪ k ə ɔː
# --------------------------------------------------
# [140/299] Processed: 281474976726956.wav
# Transcription:
# b aː ɟ aː n d̪ eː ɔː
# --------------------------------------------------
# [141/299] Processed: 281474976726961.wav
# Transcription:
# ɾ aː d̪ ɦ oː t̪ iː ə iː ə ɟ ɪ k t̪ iː ɾ uː b iː
# --------------------------------------------------
# [142/299] Processed: 281474976726960.wav
# Transcription:
# m ɛː k eː d̪ ɪ ɡ oː uː ɟ ə b eː k aː n ə n ɪ b ə m ə k ə k ə ɾ ə m aː ɾ iː
# --------------------------------------------------
# [143/299] Processed: 281474976726941.wav
# Transcription:
# b aː n iː ə s ə k uː l ə ɟ aː b ə oː ɾ ɪ d̪ ə ɔː
# --------------------------------------------------
# [144/299] Processed: 281474976726936.wav
# Transcription:
# ɾ aː s ə k oː ə k ɔː eː ɛː
# --------------------------------------------------
# [145/299] Processed: 281474976726923.wav
# Transcription:
# t̪ ʊ m ə n ɪ k ʊ d̪ ɪ ɾ ɪ ɾ ə ɟ aː b ə l ə b aː ɪ
# --------------------------------------------------
# [146/299] Processed: 281474976726921.wav
# Transcription:
# b uː n iː k ɪ k ə ɾ ɪ ɡ ɔː
# --------------------------------------------------
# [147/299] Processed: 281474976726920.wav
# Transcription:
# ə ɡ ə ɾ ə m ɪ aː p aː n t̪ ɔː
# --------------------------------------------------
# [148/299] Processed: 281474976726930.wav
# Transcription:
# j eː ɛː p ə ʈʰ ə ɾ aː m ɔː t̪ ɔː eː ɛː
# --------------------------------------------------
# [149/299] Processed: 281474976726933.wav
# Transcription:
# m ɪ ɛː k aː n aː n aː ə aː ɾ ə ɔː
# --------------------------------------------------
# [150/299] Processed: 281474976726915.wav
# Transcription:
# m ɛː ɡ aː ɪ s ə k ə n t̪ uː
# --------------------------------------------------
# [151/299] Processed: 281474976726897.wav
# Transcription:
# m ɛː b aː eː k ə aː d̪ ə ɾ uː
# --------------------------------------------------
# [152/299] Processed: 281474976726909.wav
# Transcription:
# m ɛː s ɪ aː b ə l ə p ə k aː t̪ ə uː
# --------------------------------------------------
# [153/299] Processed: 281474976726888.wav
# Transcription:
# b eː ɛː s ɪ p ə b ɪ p ə aː ɛː ə b aː eː k eː l eː ɛː k aː m ə k ə t̪ ɪ eː ɛː
# --------------------------------------------------
# [154/299] Processed: 281474976726900.wav
# Transcription:
# ɾ aː d̪ aː s iː t̪ aː t̪ ɪ b oː l iː k ɾ aː k iː k ʊ d̪ uː m uː k ə s ə n ə k ə t̪ ɪ eː ɛː
# --------------------------------------------------
# [155/299] Processed: 281474976726899.wav
# Transcription:
# t̪ ɛː ɪ k ə n ə b ə p aː iː n aː ɪ
# --------------------------------------------------
# [156/299] Processed: 281474976726911.wav
# Transcription:
# m ɛː l aː t̪ ə k iː k ɪ b ʊ l ə aː b ə l iː k ə ɡ oː
# --------------------------------------------------
# [157/299] Processed: 281474976726893.wav
# Transcription:
# b ə aː ɟ ə n ə n iː ə n ə ɟ ə l ə ɡ ɔː
# --------------------------------------------------
# [158/299] Processed: 281474976726884.wav
# Transcription:
# d̪ ə ɾ ə b aː d̪ ə iː k ə ɾ ə k ɪ ʈʰ oː d̪ iː eː ɛː
# --------------------------------------------------
# [159/299] Processed: 281474976726882.wav
# Transcription:
# ɾ aː d̪ aː n ɪ n aː ə eː ɔː ɾ ə ɡ aː ɔː ə m ɛː m aː n ə k ɔː m ə ɖ ə ɟ ɪ n k ə ɾ ə ɦ oː t̪ oː
# --------------------------------------------------
# [160/299] Processed: 281474976726881.wav
# Transcription:
# b aː n ɪ ɟ aː ɪ b ə n aː ɪ l ə iː
# --------------------------------------------------
# [161/299] Processed: 281474976726880.wav
# Transcription:
# ə aː l ə m ɪ ə k ə s t̪ eː ɟ ɔː k ɛː
# --------------------------------------------------
# [162/299] Processed: 281474976726867.wav
# Transcription:
# b aː ɛː d̪ iː ɾ eː ɟ ə d̪ t̪ ʊ eː ɛː
# --------------------------------------------------
# [163/299] Processed: 281474976717996.wav
# Transcription:
# m ɛː ə p ɪ aː p ə eː ɛː p ə s ə d̪ ə k ə t̪ uː
# --------------------------------------------------
# [164/299] Processed: 281474976718001.wav
# Transcription:
# m ɔː n ɪ k ə p iː aː b p ə aː m aː eː ə b ə n ə eː ɪ ɛː
# --------------------------------------------------
# [165/299] Processed: 281474976717977.wav
# Transcription:
# b ʊ ɡ ə ɾ uː b ə ɖ ɔː ə eː ɛː
# --------------------------------------------------
# [166/299] Processed: 281474976717980.wav
# Transcription:
# b ʊ eː k aː d̪ ɪ m ɪ ɛː d̪ eː k uː
# --------------------------------------------------
# [167/299] Processed: 281474976717984.wav
# Transcription:
# ɟ oː ɾ aː s aː m t̪ iː t̪ ɪ s uː ɪ ɾ ə
# --------------------------------------------------
# [168/299] Processed: 281474976717959.wav
# Transcription:
# oː ɾ ə aː s ə b iː ɡ ə ɡ ə
# --------------------------------------------------
# [169/299] Processed: 281474976717949.wav
# Transcription:
# k ə t̪ iː ɛː ə p ɾ ə t̪ ɪ n ə ɟ ɪ ɡ ɪ ɾ ə ɡ iː
# --------------------------------------------------
# [170/299] Processed: 281474976717972.wav
# Transcription:
# s uː ɾ ə ɟ ɪ p oː ɟ ə aː b ə t̪ ɪ ɦ ɡ ə t̪ ʊ eː ɛː
# --------------------------------------------------
# [171/299] Processed: 281474976717924.wav
# Transcription:
# ɾ aː d̪ aː k iː b ə ɟ ə ɛː t̪ ɪ b uː ə m ə ɾ ɪ b ə
# --------------------------------------------------
# [172/299] Processed: 281474976717952.wav
# Transcription:
# b ʊ t̪ iː s ʊ b ə ɾ ɟ ə ɾ ɪ k eː p iː ɟ eː ɾ ə k ə t̪ ʊ eː ɛː
# --------------------------------------------------
# [173/299] Processed: 281474976717932.wav
# Transcription:
# m ɛː aː t̪ ʊ m ɪ k s d̪ eː iː k iː b ɪ aː oː
# --------------------------------------------------
# [174/299] Processed: 281474976717910.wav
# Transcription:
# ɾ ʊ p eː t̪ ə ɾ ə b aː ɟ ə k ʊ n t̪ ə eː ɛː
# --------------------------------------------------
# [175/299] Processed: 281474976717901.wav
# Transcription:
# m ɛː ə b ə eː ɛː k ə l iː oː ɾ aː d̪ ɛː
# --------------------------------------------------
# [176/299] Processed: 281474976717905.wav
# Transcription:
# b ɛː ɟ aː ə d̪ eː
# --------------------------------------------------
# [177/299] Processed: 281474976717895.wav
# Transcription:
# b ʊ k ə l ɪ p ə ɟ aː ɾ ɪ ɡ ɔː
# --------------------------------------------------
# [178/299] Processed: 281474976717899.wav
# Transcription:
# t̪ eː t̪ ʊ n ɛː ɾ aː d̪ eː s ʊ b aː ə
# --------------------------------------------------
# [179/299] Processed: 281474976717855.wav
# Transcription:
# ɦ ə ɾ aː d̪ ɪ m eː d̪ ə s ə ɾ ə b ə iː ɟ ə aː d̪ ə
# --------------------------------------------------
# [180/299] Processed: 281474976717881.wav
# Transcription:
# eː p aː d̪ ɪ p ə ɟ ɪ s aː n aː ɪ ɛː
# --------------------------------------------------
# [181/299] Processed: 281474976717866.wav
# Transcription:
# ə ɡ ə ɾ ə b uː k ə l aː t̪ ɔː m ə m ə n aː ɪ s ə k ə t̪ ə eː ɛː
# --------------------------------------------------
# [182/299] Processed: 281474976717845.wav
# Transcription:
# b ʊ s aː ɛː d̪ iː k ə l ɪ aː b eː ɛː
# --------------------------------------------------
# [183/299] Processed: 281474976717853.wav
# Transcription:
# aː m ə n ə m ə n ɪ p ə ɾ ə s ə ɾ s eː l ə ɾ ə ɡ ə n ə
# --------------------------------------------------
# [184/299] Processed: 281474976717842.wav
# Transcription:
# ʈʰ ɪ ɾ iː ə p ə p eː ɾ ə p ə n eː ɪ ɛː
# --------------------------------------------------
# [185/299] Processed: 281474976717824.wav
# Transcription:
# ɟ ɪ p ə ɾ ɪ b aː ɾ ə k ɪ b aː ə p b ə ɾ ə ɾ aː ɔː ɾ ə m ə ɾ ə ɟ iː eː
# --------------------------------------------------
# [186/299] Processed: 281474976717837.wav
# Transcription:
# t̪ ʊ eː ɛː b l n ɔː n iː ə eː ɛː
# --------------------------------------------------
# [187/299] Processed: 281474976717844.wav
# Transcription:
# t̪ ɪ b ə l ə p ə d̪ oː k ɪ k aː b ə eː ɛː
# --------------------------------------------------
# [188/299] Processed: 281474976717819.wav
# Transcription:
# b ə k b aː n ə t̪ eː ɾ ɔː l aː ɔː k ə ɾ eː ɛː
# --------------------------------------------------
# [189/299] Processed: 281474976717836.wav
# Transcription:
# ɟ aː
# --------------------------------------------------
# [190/299] Processed: 281474976717811.wav
# Transcription:
# m ɛː ɾ oː ə ɪ aː m ə ɾ ə k aː t̪ oː
# --------------------------------------------------
# [191/299] Processed: 281474976717802.wav
# Transcription:
# t̪ eː ɾ iː d̪ ɪ b aː ɡ iː
# --------------------------------------------------
# [192/299] Processed: 281474976717805.wav
# Transcription:
# ɾ ə b iː s ə n ɪ t̪ ɪ k ə ɾ eː
# --------------------------------------------------
# [193/299] Processed: 281474976717798.wav
# Transcription:
# b ʊ b aː iː ɾ ə s uː ɾ aː ɾ ə eː ɛː
# --------------------------------------------------
# [194/299] Processed: 281474976717747.wav
# Transcription:
# k aː ɟ ɪ s ə iː d̪ ə eː ɛː ɦ ɔː t̪ iː l eː ɛː
# --------------------------------------------------
# [195/299] Processed: 281474976717738.wav
# Transcription:
# b iː k ə ɟ aː ɾ ə ɟ eː ɛː
# --------------------------------------------------
# [196/299] Processed: 281474976717756.wav
# Transcription:
# m ɛː b ə s t̪ eː ɟ aː ɡ oː
# --------------------------------------------------
# [197/299] Processed: 281474976717728.wav
# Transcription:
# b ʊ ɡ̤ ə ɾ ə m ɛː t̪ ɔː
# --------------------------------------------------
# [198/299] Processed: 281474976717793.wav
# Transcription:
# b ʊ ɟ ə ɡ ə l oː eː ɛː
# --------------------------------------------------
# [199/299] Processed: 281474976717717.wav
# Transcription:
# t̪ ʊ m ɾ oː aː m ə eː k aː t̪ ə eː ɛː
# --------------------------------------------------
# [200/299] Processed: 281474976717787.wav
# Transcription:
# t̪ ʊ ə m eː s ə ɡ aː ɪ ɾ ə eː ɦ ə n ə
# --------------------------------------------------
# [201/299] Processed: 281474976717772.wav
# Transcription:
# b aː n ɪ m oː ə t̪ eː ɛː n ə k ə ɾ oː
# --------------------------------------------------
# [202/299] Processed: 281474976717713.wav
# Transcription:
# p ʊ t̪ aː b uː ɡ ʊ ɾ aː ɪ ɾ ə
# --------------------------------------------------
# [203/299] Processed: 281474976717703.wav
# Transcription:
# b ʊ d̪ ə ɾ aː m ə t̪ eː k eː ɾ ə k ə ɾ ɔː
# --------------------------------------------------
# [204/299] Processed: 281474976717689.wav
# Transcription:
# b aː n ɪ ɛː k ə m ə ɾ eː ɛː s aː t̪ ə k ə d̪ t̪
# --------------------------------------------------
# [205/299] Processed: 281474976717764.wav
# Transcription:
# ʊ ə b ə m ɛː t̪ aː n ɪ m ɪ ɟ aː ɪ ɾ ə ɔː eː ɛː
# --------------------------------------------------
# [206/299] Processed: 281474976717758.wav
# Transcription:
# m ɦ aː ə m ə eː ɛː b ə iː eː s ə k ə s ə ɟ eː l eː ɛː ɡ eː
# --------------------------------------------------
# [207/299] Processed: 281474976717694.wav
# Transcription:
# b ɪ l ɔː ɡ ə n ə n ɛː p ɔː k aː m ə k ə t̪ uː m n ɛː k ə ɾ eː
# --------------------------------------------------
# [208/299] Processed: 281474976717685.wav
# Transcription:
# b eː ɾ oː ɟ ə b ə ɟ aː ə ɟ aː t̪ ə eː ɛː
# --------------------------------------------------
# [209/299] Processed: 281474976717682.wav
# Transcription:
# aː n ə n aː d̪ ɪ s ə k ə ɾ ə eː ə k iː s ə ɾ aː b ɛː m ə n ɟ ɪ ɾ ə m ə d̪ ɪ ɔː ə ɟ ɪ k ɪ ɟ ɔː ɾ ə iː p ɪ iː ɦ ɔː ɟ aː s ə k eː ɛː
# --------------------------------------------------
# [210/299] Processed: 281474976717684.wav
# Transcription:
# m ə d̪ ʊ ə b ə b ə eː b ə aː t̪ ɪ p ɔː t̪ ə p j ɛː ɾ ə k ə t̪ eː ɛː
# --------------------------------------------------
# [211/299] Processed: 281474976717661.wav
# Transcription:
# ʊ ə n ɪ ɛː ɦ ə m ə aː iː ɾ ə b aː d̪ ə oː
# --------------------------------------------------
# [212/299] Processed: 281474976717673.wav
# Transcription:
# b oː k ʊ ʈʰ ə k iː d̪ aː ɾ iː s ə k ə t̪ ʊ eː ɛː
# --------------------------------------------------
# [213/299] Processed: 281474976717650.wav
# Transcription:
# b aː t̪ ɛː ə b ə k ə ɾ ə p aː ɾ ɛː ə ɟ aː ɡ oː
# --------------------------------------------------
# [214/299] Processed: 281474976717646.wav
# Transcription:
# b ʊ k ə l ɪ k ə l ɪ k ə t̪ aː ɟ aː ɪ ɾ ə iː ɟ eː ɛː
# --------------------------------------------------
# [215/299] Processed: 281474976717644.wav
# Transcription:
# m aː ɟ ɪ ɾ aː t̪ ʊ m ɪ ɛː s ɛː ɾ ə ɟ aː ɪ b ɪ aː t̪ uː
# --------------------------------------------------
# [216/299] Processed: 281474976733316.wav
# Transcription:
# m ə aː k eː ɛː ɪ b eː t̪ ɪ l ɛː k eː ɛː ə b aː k ɔː n aː m ə d̪ ə ɾ ɪ b eː k eː s ə b ə eː k aː ɾ ɪ k ɾ ə m ə k ɔː s ə m ɪ p ə ɖ n ɪ t̪ ə b ə t̪ aː t̪ ʊ ɔː eː ɛː ə ʈ iː p ɛː d̪ ə ɾ ə ɔː ɟ aː t̪ ʊ eː ɛː ɔː ɾ ə b ʊ s ə b eː ɛː k aː ɾ ɪ k ə m ə k ə ɾ ə iː ɦ oː t̪ ə eː ɛː
# --------------------------------------------------
# [217/299] Processed: 281474976734784.wav
# Transcription:
# b ɪ aː k iː s ə b ə ɾ iː t̪ ə iː aː ɾ iː k aː ɟ b ə ɔː ɖ iː k ɔː b ɪ aː b ə t̪ ə m ɔː ɖ iː k eː p aː p aː d̪ eː t̪ ə eː ɛː s aː b ə k iː t̪ iː ɟ aː ɾ iː k t̪ aː ɟ m ɾ ʊ b aː ɡ ə ɾ ə m ɔː ɖ aː k ɔː b ɪ aː ɛː t̪ ɔː m ɔː ɖ ə aː k oː p aː p ə iː b eː t̪ ə eː ɛː
# --------------------------------------------------
# [218/299] Processed: 281474976734794.wav
# Transcription:
# m ʊ ɾ ə eː ɡ eː b aː d̪ ə ɛː p aː t̪ ɔː t̪ ɪ eː ɛː s aː m ɪ p ʊ aː s ɖ iː k ə ɾ ə ɛː t̪ ɔː ɟ ɪ k ə p uː p ɔː ɾ iː k iː ɾ ə s ə b ə ɟ iː s aː ɪ t̪ ɔː ə b ə d̪ iː k ɪ l ə ɾ ə b uː aː s k iː s ə b ə ɟ iː s iː l ə iː s ə b ə ɟ iː p aː n iː m ə s
# --------------------------------------------------
# [219/299] Processed: 281474976734788.wav
# Transcription:
# m ə ɾ ə eː b aː ɟ ə k ɔː n ɪ ə s ɪ k aː ɾ ɪ k ɾ ə m ɦ oː t̪ ə eː ɛː ɟ m ə ɾ ɪ b eː k eː b aː t̪ ə b ə k ɔː ə d̪ ɛː ɟ aː ɟ aː t̪ ʊ m ə ɾ ə k ə t̪ ə n ə m ɪ m ə ɟ aː k ɪ b ɪ n ə k ɔː k ɾ iː aː k ə l aː p ə ɔː oː t̪ ʊ eː ɛː ə t̪ ə l ɔː ə t̪ ə k ɪ aː t̪ ə ɛː m s ə b d̪ iː ɦ ɔː ə t̪ ɪ eː ɛː n aː k ɔː n ə k ə t̪ ə p ɛː b aː ɾ ə k ə t̪ ə eː ɛː b aː ɾ oː t̪ aː ɾ eː ɟ aː t̪ ə eː ɛː k ə p ə ɖ aː d̪ ɔː b eː ɟ aː t̪ ɪ n aː ɪ b eː ɟ aː t̪ ə eː ɛː k ə uː d̪ ə ɾ ə n ə aː d̪ eː ɾ ə d̪ ɪ n aː b ə b ə n ə k ə ɾ aː ɔː ɟ aː t̪ ʊ eː ɛː p ə d̪ ə t̪ ə n ə k ɔː k ə ɾ aː ɔː ɟ aː t̪ ʊ ɛː ɟ eː ɾ ə iː k ə ɾ iː aː t̪ ɪ eː ɛː aː t̪ ə ɛː s ʊ ɾ ə d̪ aː n ə ʊ ɾ ə l uː oː ɡ ə n ə k ɔː ɾ ɔː t̪ ɔː ɡ ɔː ɟ aː ɦ t̪ ʊ eː ɛː b aː k eː b aː t̪ ə ɟ iː k s aː l ə k iː b iː t̪ eː ɛː ɟ ə d̪ ʊ ɔː s aː l k ɪ t̪ iː s aː l ɪ ɟ iː n iː t̪ ə eː ɛː m ə m ə ɡ aː ɟ iː m ɪ k ɪ b eː k ə s ɪ k ə t̪ ə s ɪ ɾ aː ɪ d̪ iː ɟ aː t̪ ɪ eː ɛː d̪ ə ɾ ə ɡ eː ə s t̪ ɪ aː ɟ ɪ n ɛː ɡ ɦ oː n ə t̪ ə eː ɛː ɔː ɟ ə ɪ s ə b ə k ə oː ɟ aː b eː s eː ɦ oː t̪ ʊ eː ɛː aː k eː ɟ oː b ə aː m aː iː aː t̪ ɪ m aː ɦ oː t̪ ɪ eː ɛː b aː s aː t̪ iː m ɪ s ə k ɪ b ə n ɔː ə ɟ ə n ə m ə b ɪ ɟ ɛː ə b aː k ɔː m ɟ ə n ə t̪ ɪ m oː ɔː ʈ ə ɟ ə ɛː ɟ aː ɾ ɛː s ɪ s ə b ə ɾ iː s ʊ t̪ iː k ə ɾ ə n ə ɦ oː t̪ ə eː ɛː s ə b ə ɾ iː k iː s ʊ d̪ iː k ə ɾ iː ɟ aː t̪ iː eː ɛː ɟ ɛː k eː m aː eː ɪ k ɪ b aː b aː t̪ ʊ m aː k ɔː ɟ ə n s ɔː m ɔː ə d̪ ɪ k eː ɛː d̪ uː s ɪ s iː ɟ ə ɡ eː ɟ ə n ə m ɾ ɛː
# --------------------------------------------------
# [220/299] Processed: 281474976734779.wav
# Transcription:
# n aː b ɪ aː m ɪ l oː ɡ ə k ɛː s uː d̪ ə s aː k ə t̪ ə eː ɛː k aː ə p iː s m k ə ɾ ə k eː k ɔː ɟ ə oː ɾ iː n aː k ɪ eː p iː ɟ ɪ s aː m n ɪ m b ə k ə ɾ ə k ɪ b ɛː t̪ eː ɔː k oː ɔː ɖ aː n ɔː ɖ iː ɦ oː t̪ ə eː ɛː b ʊ l ə d̪ ə l ə n b eː k ə d̪ ɪ s aː p ə ɛː n ɪ t̪ ɪ m ɔː k ə ɾ aː l eː t̪ eː ɛː k iː ɟ aː d̪ ɪ s aː ə b ə k ə ɾ ɪ eː m oː b aː k iː b aː ɛː ɟ ɪ t̪ eː b ə ɾ aː t̪ iː aː ɾ ə ɡ ə ɾ ə aː t̪ iː aː ɦ oː t̪ ə eː ɛː b ɪ k t̪ ɪ s aː m ɪ m ɔː k ə ɾ ə k eː ɛː ə s aː k ə ɛː oː ɟ ə t̪ uː ɾ iː n aː k eː k eː ɾ ɪ s aː m ɪ k aː eː n ɪ s eː t̪ ɪ s aː m ɪ b ɛː ə m ɔː k ɔː ɾ k eː b ɪ k ɪ t̪ ɪ ɔː p k ə ɾ ə k ɪ b ɛː ʈʰ ə s ə k ə n ɛː ɟ ə n d̪ uː l aː k iː ɛː t̪ ɪ ɾ ə m ə m oː k ə ɾ ɪ ɛː k ə p ʊ l ə d̪ ə k iː t̪ ə ɾ ə
# --------------------------------------------------
# [221/299] Processed: 281474976734777.wav
# Transcription:
# b ɪ aː m ɟ oː uː ɾ iː t̪ ɪ ɾ ɪ b aː ɟ ə ɦ oː t̪ ə eː ɛː p ɔː ə b ɪ n ə ɡ ɔː s ə m ɪ ɟ ɦ oː t̪ ʊ eː ɛː b oː b ə p ə d̪ ə t̪ n ə k aː t̪ ʊ eː ɛː ɔː k ɪ ə ɾ ə b ɪ aː k oː ɾ iː t̪ ə ɾ ɪ b aː l ə ɦ oː t̪ ə eː ɛː b aː eː ɛː ɪ k ə s ə m ɛː d̪ ɔː ɟ aː t̪ ʊ eː ɛː ɟ ɛː s eː k eː ɟ ə b uː m ɔː ɖ aː m ɖ iː k ɟ ə m ə t̪ ɪ k iː aː ɟ aː t̪ ɪ eː ɛː p ɔː b aː m ɪ l aː n ə k ə ɾ ə k eː m ɔː ɖ aː ɔː m ɔː ɖ iː k ɪ k ʊ ɾ ə m ɪ l aː ɪ ɟ aː t̪ ə eː ɛː ə t̪ iː s b oː ɖ oː t̪ ə eː ɛː b aː m ə m ɪ s ɪ ɟ ɪ t̪ eː b ʊ ɖ ə m ɪ l ɟ aː t̪ ə eː ɛː t̪ ɔː m aː n ɔː ɟ aː t̪ ɔː b ɪ aː ɾ ɪ b ɪ aː ɔː eː ɛː t̪ ɔː p ɛː l ɪ ɡ oː l ə m l aː eː ɪ ɟ aː t̪ ə eː ɛː ɪ ɡ ʊ ɾ ə m ɪ ɟ eː ɟ aː t̪ ə eː ɛː t̪ ɔː p ɾ b ɪ aː k iː p aː t̪ ə k ə k iː ɦ oː t̪ ɪ eː ɛː p ɪ p iː ɾ eː ɪ iː aː t̪ ɪ eː ɛː b iː ɟ ɪ t̪ iː m ɪ d̪ ə iː ɟ aː t̪ ɪ eː ɛː k ɪ iː k t̪ eː l ɔː ɡ n ɔː n ɪ k ə b ə ʈʰ aː ɦ ɔː n iː ɛː k ə b ə m ə n d̪ ə p uː n ɔː eː ɛː k ə b ə l ə ɡ ʊ n ə d̪ ə n iː ɛː ɟ iː k ɪ t̪ ɔː ɟ eː s ə b ə ɾ eː k aː m p ə ɖ d̪ ə ɾ iː aː d̪ ə k iː d̪ eː t̪ ʊ eː ɛː k ɔː b ɪ d̪ aː eː b ɾ iː k ə b ɪ aː iː ɦ ɔː k ɔː ə s ɪ s ə m ɛː p ə ɦ ɪ ɡ ɔː k ɔː ɪ s ɔː m ɔː uː ɾ ə t̪ eː ɛː ɟ eː s ə b ə k ə uː p ə ɛː d̪ ə t̪ ə k ə t̪ ʊ eː ɛː ɔː ɾ ə b aː iː t̪ ɪ n aː b uː ɾ eː s ə b ʊ n ə k ɪ s ə ɡ ə b ɪ n aː s ə b ə n ə k ɪ t̪ ʊ k ə oː ɦ oː t̪ ə eː iː n aː ɪ s ə b ʊ n ə k iː ɟ eː ɦ oː t̪ iː ɟ ɛː s ɟ ɛː s p ə d̪ ɪ t̪ oː t̪ aː t̪ ʊ eː ɛː b ɛː s ɪ b s eː k ə ɾ iː ɟ aː t̪ iː uː b aː ɾ iː aː ɛː s ə m ɛː b ɾ k ə ɾ iː ɟ aː t̪ iː ɔː ɾ ə b ɛː s iː uː ɾ ɪ s aː b aː ɟ ɪ k d̪ ɪ b aː ə ɟ ɪ k ɪ ɛː s iː k ə ɾ iː aː k ɟ ɛː s ɪ k ɪ s ə m aː t̪ ə m ɛː ɾ ɔː eː b eː ɛː s iː b uː k aː ɔː ɟ aː t̪ ʊ eː
# --------------------------------------------------
# [222/299] Processed: 281474976734769.wav
# Transcription:
# k oː d̪ eː b ɡ ɔː k ə d̪ ə ɾ ə ɟ ə b ə ɟ ə n ə m ə t̪ ʊ eː ɛː b aː s ə l eː ɛː k eː b ə aː ə k eː n aː m ə d̪ ə ɾ ɪ b eː t̪ ə k ɔː ɟ ɪ t̪ ʊ ɡ̤ ə ɾ ə m ɪ k ə aː ɦ ɔː t̪ ʊ eː ɛː m aː j aː t̪ ɔː m aː l aː k eː p aː p aː n iː d̪ eː ɛː t̪ ɪ eː ɛː t̪ ɔː ə m ə t̪ ə l b eː s aː p iː s aː d̪ ɛː s ə b ə t̪ ɪ eː ɛː ɟ k ə m aː t̪ ʊ eː ɛː t̪ ɔː ə ɡ ə ɾ ə b aː b aː k ə ɪ k ə aː t̪ ɔː b aː b aː k ə d̪ t̪ ɪ eː ɛː p aː b k ə m aː ɾ ə eː b eː ɛː t̪ ɔː b aː b ə n aː k ə m aː t̪ eː ɟ aː p eː d̪ ə ɾ ə m ɪ b ə aː k iː p aː p aː ɟ aː m aː m ə m iː k ə m aː ɪ ɾ ə ɦ oː t̪ ə eː ɛː t̪ ɾ ə b eː d̪ eː t̪ ə eː ɛː m ə d̪ ə b eː ɛː k ɪ ɟ oː k ʊ iː k ə m aː ɾ ə ɾ ə t̪ ʊ eː ɛː ɔː ɾ ə p ə ɾ ə b aː s ə s ə m ɪ l ɪ t̪ ə eː ɛː t̪ ɔː ɾ ə b iː p iː s aː p ə aː k ə t̪ ʊ eː ɛː
# --------------------------------------------------
# [223/299] Processed: 281474976734774.wav
# Transcription:
# ɦ ə m ə aː eː s ə m aː ɔː ɟ ə m ɛː t̪ ɔː ɟ ə ɾ ə p ɪ aː k ə ɾ aː ɟ aː t̪ ʊ eː ɛː m ɔː ɖ aː k uː oː ɪ aː m ɔː ɖ iː k t̪ ə d̪ ə ɾ ə ɾ iː t̪ eː ɾ ɪ b aː d̪ eː ɦ oː t̪ ə eː ɛː ɟ ɛː s ɪ ɛː s ə b ə n s ə p l ɛː ɦ ə m ə b ə t̪ aː t̪ ə eː ɛː k ɪ b aː ɾ ə ɡ̤ ə ɾ ə m ɪ m ɔː ɖ aː k oː ɪ aː ɔː eː ɛː t̪ ɔː p ɪ ɛː l ɪ ɛː m ɔː ɖ iː b aː eː aː ə ɡ eː t̪ iː ɾ k ə d̪ aː k ə k eː ɟ aː ɡ eː uː ɖ iː k eː b ə iː aː p aː p aː p ɾ ə k ɪ ɾ ə b eː ɛː p ə ɾ ɪ s ɪ d̪ aː ɾ ə n ə k ʊ l eː ɛː k ɪ aː t̪ ə eː ɛː ə ɡ ə ɾ ə b ə n ɪ s ə b k ə l ə ɡ ə t̪ ʊ eː ɛː t̪ ɔː p ɪ ɾ ɪ s t̪ eː d̪ aː ɾ ə n ə k ʊ l aː t̪ ə eː ɛː m ɔː ɖ ə b aː k ɪ ə ɾ ə b aː ɪ n ə k uː p ə iː s ə d̪ ɛː k ɪ aː t̪ ə eː ɛː ɟ ə k aː ɦ oː t̪ ə eː ɛː ɾ oː k p eː ɛː t̪ ɪ p ɪ aː ə eː ɛː ɟ ɪ t̪ iː d̪ ə p ə eː ɛː p ɛː d̪ eː ɛː t̪ ɪ ɾ ə ɛː ɟ ə aː ɪ ɡ eː b aː k eː aː b eː m ɖ iː k iː ə ɾ ə m l ɔː ɖ ə m ɔː ɖ aː k eː ɡ̤ ə ɾ ə b ə eː ɟ aː ə m eː t̪ ɔː k uː d̪ ə k uː l ə b ə ɾ ɪ aː t̪ ə eː ɛː m ɔː ɖ iː k ə ɪ k ə p ɾ aː l ɛː ɟ aː t̪ ə eː ɛː b aː k iː ɡ̤ ə ɾ ə b aː n ə k aː ɪ l ɛː ɟ aː t̪ ə eː ɛː ə b aː ɟ ə b ə eː n ʊ k aː ɟ ɪ ɛː k oː iː p d̪ ə s ɪ iː ɟ ə ɟ ɛː s ɔː ɟ eː ɟ ə b ɪ n ə l eː ɟ aː n iː l ə eː ɛː ɟ aː t̪ ə m ɔː ɾ iː k ə aː eː t̪ ɔː b ɪ t̪ oː m ə t̪ ə l ɔː k ə k ɪ b ɪ aː s t̪ eː ɛː ɟ aː ɪ b eː ɟ t̪ ɛː t̪ p ɾ ə b aː k iː b aː n ə m ɔː ɖ iː b aː ɪ ə k ɪ ɡ̤ ə ɾ ə b aː iː p iː ɾ ə ɟ iː n eː ɦ ə k aː eː ɟ ə d̪ s t̪ ə eː ɛː ɟ iː ɟ ɪ p ə iː n eː k ə ɾ aː ɪ b ɪ k eː b aː m ɪ b ɪ aː k iː t̪ aː ɾ iː k ə t̪ ɪ l t̪ aː iː k aː k aː ɦ oː t̪ ʊ eː ɛː ɔː ɾ ə t̪ iː k ə aː l ə m ə n ə s ə b ə n ə k ɔː t̪ aː ɾ iː k ə n ə k ə l ə b aː ə t̪ ə eː ɛː t̪ iː k ə l ə ɡ ʊ n ʊ k ə k ɪ eː ɛː d̪ eː n aː m ɔː ɖ iː b eː ɛː ɟ aː t̪ ə eː ɛː d̪ iː k ə aː l ɛː k ɪ m ɔː ɖ aː b aː ɪ k eː b ə ɾ ə m ə m ɔː ɖ ɪ m ɔː ɖ aː k ə t̪ ə t̪ ʊ l ə b ə s ə ɾ aː t̪ eː ɛː aː m aː ɾ ə k ə b aː s ə b uː s ʊ l ɛː ɟ aː t̪ ə eː ɛː p b ə n aː ɾ iː k ə b ə ʈ aː l ə t̪ aː d̪ oː t̪ iː ɦ oː t̪ iː t̪ l ɛː k ɪ ɟ aː t̪ ə eː ɛː p ɪ ɾ ə b aː k b aː d̪ ə m ɔː ɖ iː m aː eː k ə ɾ k ə aː k ə t̪ ə aː ə ɾ ə eː ɟ aː t̪ ʊ eː ɛː m ɔː ɖ iː b aː ɪ k iː b ə ɾ ə k eː ɾ ə k aː iː s uː ɾ uː ɡ eː ɟ aː t̪ ɪ eː ɛː l ə ɡ ə n ə k ɪ t̪ ɟ aː t̪ ɪ eː ɛː p ɪ t̪ ɪ s eː l oː ɦ oː t̪ ʊ b ɛː t̪ aː iː ɦ oː t̪ ɪ eː ɛː b aː k eː b aː d̪ ə m aː ɖ ə b uː t̪ ʊ eː ɛː m ə n ə m aː ɖ eː ɛː k ɪ ɾ ɪ n aː b aː t̪ ə p ɪ ɛː t̪ ʊ eː ɛː b aː p ɛː n aː t̪ ɪ ɛː m ɔː ɖ iː k ə m ə ɡ ə m aː m ɔː ɾ aː k ɪ ɡ̤ ə ɾ ə m b aː p ɛː n aː ɔː ɟ aː t̪ ʊ eː ɛː m ɔː ɖ aː k eː ɡ̤ ə ɾ eː ɛː ə b aː t̪ ə p ɛː n aː ɟ aː t̪ ʊ ə ɛː b aː t̪ ɪ n aː k eː k eː d̪ ə b ɾ aː ɟ ə ɟ aː t̪ ɪ eː ɛː b ə ɾ aː k ʊ l eː ɛː k ɪ ɟ aː t̪ ə eː ɛː t̪ ɾ ə b ə ɾ aː ɟ ə l eː ɟ aː ɪ k ɪ b ɪ t̪ eː ɛː s eː ɛː s ə b ə b ə uː ə k b ɪ l aː k ə ɾ aː eː ɪ k ɪ l aː t̪ ə eː ɛː p ə ɾ ə b ə t̪ p ɪ b aː ɔː ɟ aː t̪ ʊ eː ɛː d̪ ʊ aː ɾ b uː k ɔː ɟ aː t̪ ʊ eː ɛː ɾ ə ɛː s ɪ s ə b ə ɾ iː p aː m ə b ɪ ɾ eː p iː t̪ ɪ ɾ ɪ b aː ɟ ə eː ɛː ɟ ɔː k ə ɾ n ə p ə t̪ ə eː ɛː ɔː ɾ k aː
# --------------------------------------------------
# [224/299] Processed: 281474976734780.wav
# Transcription:
# b aː k eː ɾ iː t̪ ɾ ɪ eː b aː ɟ ə n ə k ɔː k aː t̪ ə ɾ iː k aː ɦ oː t̪ ʊ eː ɛː t̪ ə ɾ iː k ə t̪ ə n ɟ aː ɦ oː t̪ eː ɛː ɪ ɟ ə b ə b ɪ aː ɦ oː t̪ ʊ eː ɛː t̪ ɔː p ɛː n ə aː k iː t̪ aː ɾ ɪ k aː ɾ ɪ k m ɪ b aː ɾ iː ɟ aː t̪ ɪ eː ɛː k ɔː ə s ɪ d̪ ə n aː k aː ɔː n aː ɟ k ə eː ɛː ɦ ə t̪ ʊ eː ɛː ɪ ɾ ə ʊ ɾ ɪ t̪ ə ɾ iː k aː s iː ɦ oː t̪ ʊ eː ɛː ɟ aː s ɪ k eː t̪ ʊ n ɪ n aː ɪ ɡ ə d̪ uː l aː b ə ɾ aː t̪ aː ɛː b t̪ ɔː b aː k aː ɪ t̪ aː b oː ɖ aː k ʊ b ɛː ʈʰ aː ɾ ɔː ɟ aː t̪ ʊ ɾ ɛː s p ɪ d̪ ʊ l ə n aː t̪ ɪ eː ɛː p ɟ ə m aː ɾ aː ə ɖ aː ɪ b iː aː t̪ eː ɛː ɟ ɦ aː ɡ ə aː ə ɛː d̪ ə k ə ɾ iː k eː b aː k aː n aː p iː m ə ɦ oː t̪ ʊ ɾ k aː n ɔː k iː n ɔː k aː ɪ b eː k eː b aː ɪ ə d̪ uː ɟ aː d̪ eː l ə n ə k ɪ b ə oː t̪ oː t̪ ʊ k ɪ ə t̪ ə eː ɛː p ɔː t̪ oː t̪ ʊ k ɪ b eː k eː b ɾ aː t̪ ə m ɪ n ɪ b l ɛː ɟ aː ɟ aː t̪ ʊ eː ɛː ə k eː n ɛː k aː ɾ aː m ə k ə t̪ ə eː ɛː p ɾ ʊ b aː k eː b aː s ə iː ɾ ə k ə l n ɛː d̪ aː ə ɦ oː t̪ ʊ eː ɛː k ə n ɛː d̪ aː n ə k aː ɟ ɪ t̪ ɾ ə b ɛː t̪ ɔː ɟ aː t̪ ʊ eː ɛː aː t̪ ə p iː ɾ eː ɛː ɟ aː t̪ ə eː ɛː m ə m iː p aː p ə k ə t̪ ə m ɔː ɖ iː k eː ɟ eː ɾ ə ɦ aː t̪ ə eː ɾ ɛː eː k eː b aː ɾ b ɪ n ə k ʊ k ə t̪ ə b ə n m ɛː m ə oː t̪ ʊ eː ɛː k ə n d̪ ə n ə k ɪ b aː d̪ ə ɪ ɟ aː p ʊ ɾ ɔː ɟ aː t̪ ʊ eː ɛː t̪ eː s aː t̪ ə k ɾ ə b ə n ə l eː ɛː ɟ aː t̪ ə eː ɛː p eː ɾ eː ɦ oː t̪ ə eː ɛː ɡ ʊ d̪ ə b ə ɾ iː ɟ aː t̪ ɪ eː ɛː d̪ aː n ə b eː ɟ aː t̪ ə eː ɛː d̪ aː ə b ə ɡ eː ɡ ə d̪ ə m aː m ə ɡ ə ɾ iː aː t̪ ɪ eː ɛː b ə aː iː b iː m ɛː ɟ oː uː t̪ ɛː ɪ ɟ ə ɟ aː t̪ ʊ ɛː ɪ s aː ɾ iː oː ɾ aː t̪ ɪ eː ɛː ɟ uː t̪ aː ɦ oː ʊ t̪ aː ə b aː p ə s t̪ ɪ ɛː n ə b eː k aː eː d̪ uː l ɔː aː k ə ɾ ɔː ɦ oː t̪ ə b ə ɟ oː d̪ aː m aː ɡ ə t̪ ʊ eː ɛː ɟ oː t̪ ɔː m ɪ ɟ aː t̪ ʊ eː ɛː p ɪ b aː k ɪ b aː d̪ uː l ə d̪ ə p ɔː n ə oː t̪ ə k eː d̪ aː t̪ ə eː ɛː k ə m ə ɾ aː m ɪ uː ʊ l aː b aː t̪ iː k ə ɾ aː ɪ eː ɛː t̪ ɔː p ɾ s aː ɾ iː ɦ oː t̪ iː eː ɟ uː d̪ ə ɾ ə b aː ɟ ə p oː k ə t̪ ɪ ɛː t̪ ʊ b aː eː n eː k ə b ɛː n ə p ə t̪ ʊ oː d̪ b uː l aː k d̪ ə ɾ ə b aː ɟ ə p ə k ə b eː k ɪ b aː d̪ ə b ʊ l ə b aː t̪ eː ɟ aː ɪ b eː b aː t̪ ə eː ə d̪ ə l ə n ɦ oː t̪ ə iː aː ɾ ə k aː ɔː ɟ aː t̪ ʊ eː ɛː b ɪ d̪ aː t̪ ə t̪ aː eː ɛː b ɪ ɾ aː ɟ eː ɟ aː t̪ ə eː ɛː b ɪ l aː iː k aː ɛː k eː ɛː ə s ə aː ɟ aː p eː ɛː ɔː s ə ɾ ə b ə t̪ p ɪ b aː ɔː ɟ aː t̪ ʊ eː ɛː s ɾ ə t̪ ɪ b aː ɟ eː k ɪ b aː d̪ ə ɛː ɡ̤ ə ɾ ə m ɪ ɛː b ɔː s ə t̪ ɛː d̪ ʊ l ə b ʊ ɟ ə n ɪ k oː s iː k aː p aː d̪ ə ɔː ɾ ə b aː ɔː ɟ aː t̪ ʊ eː ɛː p aː n iː b ə ɟ ə k ɪ d̪ ə d̪ t̪ ɔː eː ɟ aː t̪ ʊ eː ɛː ɾ ə d̪ aː ɾ ə k ɪ b aː m ə p aː ɪ b oː ɾ ə k eː d̪ ə ɛː ə d̪ iː t̪ eː ɾ ə k ə s ə t̪ ɪ eː ɛː iː k ɪ k ə ɾ ə k eː ɔː ɾ ə t̪ ə ɛː ɟ ɪ k aː k ə t̪ iː eː ɛː ʈ iː k ɔː k ə t̪ ɪ eː ɛː d̪ uː l ə t̪ ə l ə n ɪ k ɪ p ə iː s aː ɾ eː t̪ iː eː ɛː b aː ɡ ə b eː t̪ b ɛː ʈʰ aː t̪ ə eː ɦ aː d̪ ə d̪ ʊ l ə n ə k ɔː ɟ iː t̪ ə eː ɾ b aː k ɪ b aː d̪ ə ɾ iː ə s aː ɾ ɪ b iː t̪ ɪ ɾ ɪ b aː d̪ ə ɦ ɔː ɾ ə ɛː s ɪ t̪ iː ə l aː ɔː ɟ aː t̪ ʊ eː ɛː k aː d̪ ə k uː ɾ iː ɟ aː t̪ ɪ eː ɛː t̪ ɔː ɟ ɪ s ə b ə k ə uː t̪ uː ɾ eː ɛː b ɪ ɾ iː ɪ ɟ aː n ə s ɪ k ə ɾ eː ɟ aː t̪ ə eː ɛː b aː ɪ b ə d̪ ə m oː t̪ iː k aː iː ɦ oː t̪ ɪ ɛː ɔː p ɪ t̪ eː iː ɔː ɾ ə b ɪ iː s ɪ m eː ɟ ə b d̪ uː l ə ɡ ə l ə ɡ ə ɡ̤ ə ɾ ə n aː t̪ ə eː ɛː t̪ ɔː k ə m b ə ɾ aː m ɪ ɛː ə k aː k eː t̪ ə eː ɛː m ɔː ɖ aː k iː d̪ k ə t̪ ʊ aː ə k uː k ə t̪ ɪ eː ɛː p ɪ ə d̪ uː l ə n ə b aː eː ɾ ə k ə uː n eː ɛː d̪ eː t̪ ɪ ɛː t̪ ɔː s iː s ə ɾ eː ɾ iː t̪ ɪ ɾ ɪ b aː ɟ ə ɛː ɟ oː ɔː ɟ ɪ n ə k ɔː ə ɟ ɪ t̪ ə ɾ iː k aː ɦ oː t̪ ʊ eː ɛː s m ə m ɪ k ə ɾ aː t̪ iː eː m ə m iː t̪ aː ɾ iː b ʊ aː ɾ ə b ɪ k ə k ə b aː ɟ aː t̪ iː ɡ oː ɾ aː ɾ iː ɟ b ə ɡ ə ɾ ə m aː ɟ aː k eː ɛː t̪ ɔː k ɔː ɾ aː ɾ iː p ə b aː iː ɟ aː t̪ iː eː b aː ɡ ɪ k ə ɾ iː aː oː aː ə ɾ ə ɔː n aː ɪ ɟ aː t̪ ə eː ɛː
# --------------------------------------------------
# [225/299] Processed: 281474976734767.wav
# Transcription:
# n aː m ə p ə aː k ə ɾ ə ɟ ɪ d̪ ə ɾ ɪ eː k aː ɟ ɛː b ə p ə ɖ ɪ t̪ uː l aː ɔː ɟ aː t̪ ʊ eː ɛː p ə ɾ iː k ɛː s b ɪ t̪ ə b ə k ə ɾ iː b ʊ l aː ɔː ɟ aː t̪ ʊ eː ɛː b ʊ k ə aː k ə ɟ ə n ə m ə t̪ ɪ t̪ iː d̪ eː k ɪ ɔː b aː k ə n aː ə ɾ aː ɾ s iː k ɔː n aː m ɪ ɾ aː s iː p ɛː t̪ ə n ə s b ɪ ə p ʊ t̪ ə aː ɛː k ɪ ɟ aː t̪ ʊ eː ɛː ɔː ɾ ə ɔː b eː iː b aː k ɔː n ɛː s ə b ə d̪ ə ɛː k ɪ n aː m ə p ʊ t̪ aː ɪ b eː p ə ɖ n ɪ t̪ ə d̪ eː b ʊ n aː m ə b ə t̪ ɛː k ə ɟ aː t̪ ʊ eː ə b ə t̪ ʊ m ɛː ə l ə b ə t̪ ɔː ə d̪ iː k eː ɛː n ə iː eː ə ɡ ə ɾ ə n aː ə l ə ɡ ə ɾ ɔː t̪ ɔː t̪ ɔː m ə p ɔː k ɔː t̪ ə k ɔː k oː iː n aː m ə b aː eː ə ɾ ə p ɪ d̪ oː n ə eː d̪ ə n l ɟ ə ʊ l aː eː ɡ ɛː
# --------------------------------------------------
# [226/299] Processed: 281474976734768.wav
# Transcription:
# ...
# --------------------------------------------------
# [271/299] Processed: 281474976733763.wav
# Transcription:
# b ɪ aː k iː ɾ iː t̪ ɪ ɾ ə b aː ɟ ə n ə ɔː ɾ ə d̪ ɪ n aː ɔː ɾ ə s ə m ɪ k ɛː s ɪ t̪ ɛː ɦ oː t̪ ʊ eː ɛː ɟ eː k ə p ə ɖ ɪ n ə ɟ iː t̪ ɛː k ə t̪ ə ɛː k ɪ k ɔː n ɪ s ɪ d̪ ə n aː k aː s iː ɟ oː b ɛː iː t̪ eː l ə k ɛː s ə ɖ ɛː ɡ ɔː ə t̪ ə t̪ ɪ k aː b ə ɖ iː ɔː ɾ ə b uː ɾ eː p ɪ ɛː k ə b ɪ ɟ aː k iː eː s ə iː t̪ ə d̪ ə b aː eː p ə ɖ t̪ ɪ t̪ eː ɛː k ə ɖ ə iː p ə ɖ ɪ iː eː ɛː
# --------------------------------------------------
# [272/299] Processed: 281474976733774.wav
# Transcription:
# m ə ɾ iː b eː k ɪ b aː d̪ ə k ɪ ɾ ɟ aː k ə ɾ ə m ə m eː k ɪ t̪ ə eː iː k aː ɾ ɪ k ɾ ə m ə oː t̪ ə eː ɛː m b ɪ n ɛː n aː m ə ɛː ɔː ɾ ə b eː k aː ɪ k uː ɦ oː t̪ ə eː ɛː m ə ɾ ɪ m eː k eː b aː t̪ ə k ɪ ɟ aː k ə ɾ ə m ə m ɪ b ɔː s eː k aː ɾ ə k ɾ ə m ə ɦ oː t̪ ə eː ɛː ɟ ɛː s ɪ k eː b ɪ n ɛː n ɛː l aː b ɔː ɾ ə p ɪ ɾ ə b n ə aː t̪ ɔː l ə ɡ aː ɔː b ɪ n iː k eː m ə ɦ ɔː p ɛː ɔː ɾ ə ɡ ɪ n ə k eː p ə k ə l t̪ ɪ aː ə d̪ ɔː d̪ ə ɾ ə b ɔː ɾ ə ɡ ɪ n ə ɾ ə t̪ ɪ l ɛː ɟ aː b ɔː m aː b eː ʈʰ aː b ɔː k ɪ ɾ ə b ɪ n ɪ m aː p ɛː k ɪ b iː l ə ɡ aː ɪ k ɪ m ə n ɛː l aː ɡ ɔː ə ɾ ə k eː k ə p ə ɾ aː p ə eː ɛː n aː ɪ k eː t̪ ə b ə p ɪ ə l eː ɛː ɟ aː t̪ ə eː ɛː ɟ eː iː s ə b ə k aː t̪ ɪ k ɾ ə m ə ɦ oː t̪ ə ɛː p ɪ n m ə ɾ ɪ b eː k eː aː eː ɛː
# --------------------------------------------------
# [273/299] Processed: 281474976733775.wav
# Transcription:
# k iː ɾ ɪ aː k ə l ə m ə m eː k ɔː k oː b ɪ ɾ aː ɔː ɟ aː t̪ ʊ eː ɛː k s ɪ k ɪ ɾ ɪ ə k ə ɾ ə m ə m ɪ aː s ə p ə ɾ ɔː s ə k eː s ə b aː ɟ aː t̪ ə eː ɛː m b eː aː iː ɟ aː t̪ ə eː ɔː ɾ ɪ s t̪ eː ɟ aː d̪ ə s ə b aː iː ɟ aː t̪ ə eː ɛː b ə s m ɛː l aː ə k ʊ p oː ɖ ə k eː ɟ aː t̪ ʊ eː ɛː s ə b ə aː t̪ ə eː ɛː ɦ ə m aː iː s ə m aː ɪ ɟ ə n eː m ɛː l aː ə k oː n ə ɛː iː ɟ aː n iː t̪ eː t̪ eː ɟ ə t̪ ɪ k aː k ə ɾ ɟ ə s ə m s aː ɡ aː ɾ k ə m eː
# --------------------------------------------------
# [274/299] Processed: 281474976733745.wav
# Transcription:
# ɾ ə
# --------------------------------------------------
# [275/299] Processed: 281474976733780.wav
# Transcription:
# m ə ɾ ɪ b eː k eː b aː ɟ ə p aː t̪ iː ɦ oː t̪ ɪ ɛː t̪ ɔː k aː k ə aː p ə s ɔː ɟ aː t̪ ʊ eː ɛː b aː m ɪ b uː aː ɦ oː t̪ ə eː ɛː m aː l ə k uː ə aː ɦ oː t̪ ə eː ɛː k iː ɾ oː ɦ oː t̪ ɪ eː ɔː ɾ ə s ə b k iː ɦ oː ɪ t̪ ɪ eː ɛː s aː ɪ t̪ ɔː ɦ oː t̪ ʊ eː ɛː ɔː ɾ ə p aː iː ɦ ə t̪ ʊ eː ɟ eː iː s ə b ə iː p ə s ɪ ɟ aː t̪ ɪ eː ɛː
# --------------------------------------------------
# [276/299] Processed: 281474976733771.wav
# Transcription:
# ɔː ɾ ə k ɔː iː ɟ ə ɾ uː ɡ iː b aː t̪ oː eː ɪ b ɪ aː k iː s uː t̪ ə k ə t̪ aː ɪ s ə k ə t̪ ɔː b ɪ aː m ɪ t̪ ɔː s ə b ə ɟ ɪ ɾ uː ɾ iː b aː t̪ oː t̪ ɪ ɛː m ɛː t̪ ɦ oː ɾ ə b aː t̪ iː ɦ oː t̪ ɪ eː t̪ ɪ k ə ɾ ɔː b aː eː s ɪ ɾ ɔː l ə ɾ aː iː ɟ aː ɪ n eː ɔː ə ɡ eː ɟ iː s ə b ə ɟ ə ɾ b ə ɾ iː b aː t̪ eː ɦ oː t̪ ɪ eː ɛː b ɪ aː m ɪ
# --------------------------------------------------
# [277/299] Processed: 281474976733751.wav
# Transcription:
# n aː m ə d̪ ə ɾ ɪ b eː b aː iː k aː k ɪ k ɪ ɾ ə m ə m ɪ k aː k aː s aː m aː n ɪ ə l ə ɡ ə t̪ ʊ eː ɛː ə b ə n ə k ɔː s aː m ə n uː ɾ eː ɛː ə l ə ɡ ə t̪ ʊ eː d̪ aː k eː l ɛː aː ə b ə n ə ɦ oː t̪ ʊ eː ɛː ɔː ɾ ə b ə n ə k eː b aː d̪ ə m ɪ n aː m ə d̪ ə ɾ ɔː ɟ aː t̪ ʊ eː ɛː k ə l aː b aː s aː m eː k ɪ ɾ iː k ɪ ɔː ɡ ʊ aː iː ɟ eː s ə b ə k iː ɟ ə ɛː
# --------------------------------------------------
# [278/299] Processed: 281474976733349.wav
# Transcription:
# k aː ɾ ɪ k ɾ ə m ə m aː b ə n ə k iː aː m ɪ k eː l ə ɡ ə t̪ ɪ eː ɛː ɔː ɾ ə d̪ aː b ə t̪ ə b ə n t̪ eː s ə b aː d̪ aː b ə t̪ ə k ɔː s eː b ʊ ɾ ɔː s aː m aː m ɛː t̪
# --------------------------------------------------
# [279/299] Processed: 281474976733344.wav
# Transcription:
# ɡ̤ ə ɾ ɛː ɦ oː t̪ ə eː ɛː b ə ɾ ə p ə ɖ ɪ t̪ ə ɟ iː t̪ ə p ə b aː eː k oː t̪
# --------------------------------------------------
# [280/299] Processed: 281474976733348.wav
# Transcription:
# k aː t̪ ʊ m ə t̪ ɔː k ə ɾ ɪ b ɪ b ʊ t̪ ə ɾ ə iː k ə p ə ɖ ɪ t̪ ə ɟ iː b oː p aː t̪ ə eː ɛː
# --------------------------------------------------
# [281/299] Processed: 281474976733337.wav
# Transcription:
# b aː iː d̪ ɪ b aː ɪ n ə ɦ ʊ t̪ ə ɾ iː k ə p ə ɖ ɪ ɖ ə ɟ iː b ə t̪ aː t̪ ə eː ɛː
# --------------------------------------------------
# [282/299] Processed: 281474976733340.wav
# Transcription:
# p uː ɾ iː s ə b ə ɟ iː p aː n iː ɾ ə aː ɪ t̪ ɔː ɾ ə s ə k ʊ l aː d̪ ə eː iː b uː ɾ ɔː
# --------------------------------------------------
# [283/299] Processed: 281474976733319.wav
# Transcription:
# b ʊ ɛː p oː p aː m aː m aː m ɔː s iː m ɪ ɦ s ə b ʊ l aː ɪ ɟ aː t̪ ə eː ɛː
# --------------------------------------------------
# [284/299] Processed: 281474976733324.wav
# Transcription:
# n aː m ə d̪ ə ɾ eː ɛː k aː ɾ ɪ k ə k oː p ə l ɪ n ɪ ə ɟ iː k ə t̪ ə eː ɛː
# --------------------------------------------------
# [285/299] Processed: 281474976734133.wav
# Transcription:
# t̪ iː ɾ ɪ aː k ə ɾ ə m ə m ɛː s ə b ə t̪ ɪ ɟ aː ɟ ə ɾ uː ɟ iː eː oː t̪ ʊ eː ɛː ɡ̤ ə ɾ ə k eː p ʊ ɾ ə ɦ oː t̪ ə eː ɛː d̪ aː ə d̪ ɪ b ɔː
# --------------------------------------------------
# [286/299] Processed: 281474976734114.wav
# Transcription:
# b ɪ aː k eː ɾ iː t̪ iː ɾ ɪ b aː ɾ ə k ɔː d̪ ɪ n aː ɔː ɾ ə s ə m ɛː p ə ɖ ɪ d̪ ə ɟ iː t̪ ɛː k ə t̪ ə eː ɛː
# --------------------------------------------------
# [287/299] Processed: 281474976734112.wav
# Transcription:
# b ɪ aː k ɔː ɾ iː t̪ iː ɾ ɪ ɟ aː ɾ ə k ə s ə m ɪ ɛː p ə ɪ t̪ iː ɟ iː b ə s aː b ə t̪ ə eː ɛː ɔː ɟ eː s ə b ə ɾ eː d̪ iː k iː ɾ ɪ b ə ɾ ə k ə ɾ ə p ɛː k ə ɾ ə ɟ aː t̪ ə eː ɛː
# --------------------------------------------------
# [288/299] Processed: 281474976734107.wav
# Transcription:
# ɟ ə n ə m ə t̪ eː l ɛː k ɪ n aː m ə d̪ ə ɾ ɪ b eː k eː k aː ɾ ə k ə ɾ ə m ɪ ɟ ə ɾ ə ɟ ɪ b aː ɟ eː ɛː k b ɛː t̪ ɔː t̪ ə ɡ aː b ə n ə t̪ ʊ eː ɛː d̪ ə s ɡ ɪ n aː k ɔː b ɪ aː ɾ ə d̪ ɪ n aː k ɔː ɟ aː t̪ eː ɾ eː d̪ ɪ n aː k oː ə ɡ ə aː ɾ ə b aː m ɪ m ʊ l aː ɟ aː eː ɛː t̪ ɔː b ɪ ɾ ə t̪ ə ɡ aː b ə n ə t̪ ʊ eː ɛː p ə n t̪ ə l ə t̪ ə n aː k ɔː ə ɟ aː t̪ ʊ t̪ ə ɛː ɟ d̪ ɾ aː ə k ɔː
# --------------------------------------------------
# [289/299] Processed: 281474976734104.wav
# Transcription:
# n aː m ə d̪ ə ɾ ɪ b eː k eː k aː ɪ ɾ ə k ə ɾ ə m ə m ɛː p aː ə ɖ ɪ t̪ ɪ t̪ ə k ə t̪ ʊ eː ɛː
# --------------------------------------------------
# [290/299] Processed: 281474976734100.wav
# Transcription:
# n aː m ə d̪ ə ɾ ɪ b aː eː t̪ ə n aː ə l oː ɡ ə n ə n ɪ ɛː k ɪ ɡ aː ɟ iː k eː t̪ ɪ s aː m ə ʈ aː ɾ ə ɟ aː t̪ ʊ eː ɛː
# --------------------------------------------------
# [291/299] Processed: 281474976734101.wav
# Transcription:
# n aː m ə d̪ ə ɾ ə b iː k eː k aː ɾ ɪ k ɾ ə m ə m ɛː s ə b ə ɾ iː ɾ ɪ s t̪ eː ə ɾ ə b ʊ l aː ɟ aː t̪ ə eː ɛː ɔː ə ɾ ə b ə n ə b ə ɡ eː ɾ aː ɦ oː t̪ ʊ eː ɛː b aː t̪ ɪ ɛː m ə k ɪ t̪ n ɪ t̪ ə ɡ aː b ə d̪ ə ɡ ɔː ɾ ə s ə b ə ɾ eː ə s aː ɾ ə n ɛː k aː n ə b ə k eː ɾ aː k ə b aː ɔː ɟ aː t̪ ʊ eː ɛː ə k ə n ə k eː b aː d̪ ə ɔː ə t̪ ə b ə n aː m ə t̪ ə ɾ ə ɔː ɟ aː t̪ ʊ eː ɛː ɔː ə b aː k eː b aː d̪ l ə ɾ ɪ k aː j ɛː l ə l ɪ k iː k eː m aː m aː k eː ɦ aː t̪ ɪ eː p ə aː b ə t̪ ʊ eː ɛː ɔː p ɪ s ə b ə ɾ eː ɡ̤ ə ɾ ə b eː ɛː p ə aː ə p ɛː n t̪ ə eː ɔː p ɟ l ə d̪ ɪ d̪ aː ɦ oː t̪ ə eː ɛː
# --------------------------------------------------
# [292/299] Processed: 281474976734132.wav
# Transcription:
# k ɪ ɾ ɪ aː k ə ɾ ə m ə k ɔː k aː m ə ɟ aː ɪ t̪ ə ɾ b ə ɾ ə ɔː b ə iː aː j aː p eː ɾ ə k oː iː t̪ aː b ʊ ɾ ə b ɛː ɾ aː k ə t̪ ə eː ɛː ɔː b aː eː ɛː p iː t̪ aː d̪ ə ɾ ə k ɔː m aː l ɪ k iː d̪ oː t̪ ʊ k aː ɛː b ʊ d̪ eː t̪ ʊ eː ɛː
# --------------------------------------------------
# [293/299] Processed: 281474976734097.wav
# Transcription:
# b ə aː ɛː ɪ b ɪ k aː ɾ s ə b ɪ ɾ ə n aː n ə ɦ oː t̪ ʊ eː ɛː ɔː ɾ ə n aː n ə ɪ b eː k aː s ə n ɟ aː k oː ə ɾ eː s aː t̪ ɪ eː ɛː ə k ɪ aː t̪ ə eː ɛː t̪ ɔː s aː t̪ iː ɾ ə k ɪ ɟ aː t̪ ə eː ɛː ɟ aː k eː t̪ ə p eː ɛː b aː k iː t̪ ɪ k eː b iː t̪ ə ɾ ə s uː ə ɾ ə b oː t̪ ʊ k ɛː ə t̪ aː k eː t̪ ə p eː ɛː ɔː ɾ ə l uː ɪ ɾ ə k ə k eː aː t̪ ə eː ɛː m ɪ ʈ ɪ k aː p ɛː ɟ aː d̪ ə eː iː k ə iː p eː ɛː ɔː b aː k eː b aː ɡ ə p ə ɪ d̪ ə ɟ iː b ʊ l aː ɟ aː ə n eː ɛː m p ə ɾ n ə ɟ eː b ʊ l aː ɪ k ɪ p ə d̪ iː aː b ə t̪ ə eː ɛː t̪ ɔː p ə ɾ n iː aː ɪ k ɪ p ɪ ɾ ə ɟ eː ɾ ə b ə d̪ aː ɾ ə t̪ aː ɾ iː p aː ɾ iː b ʊ d̪ aː b ə t̪ ə eː ɛː k ɪ k ə b ə n aː m ə k ə ɾ ə ɾ oː ɡ ɔː ə t̪ ə k ə b ə k aː ɡ ɔː p ɪ ɾ ə b aː k ɪ b aː n ə n aː m ə ɡ ə ɾ oː t̪ ʊ eː ɛː t̪ ə ɡ aː b ə n ə t̪ ʊ eː ɛː b aː t̪ eː k eː t̪ ə ɛː t̪ ə ɡ aː b ə d̪ ə n ə ɛː ɔː b oː ɡ̤ ə ɾ ə k eː k uː d̪ ə l ə d̪ ə l aː n ə b ʊ ɡ eː ɛː ɾ aː b eː ɛː ɦ aː ə b ə n ə b ə b ɛː ɾ aː ɦ ʊ t̪ ʊ eː ɛː ɾ ɪ s t̪ ɪ d̪ aː ɾ ə b ə ɡ ə ɾ ə s aː m ə ɪ l oː t̪ ʊ ə eː ɛː t̪ ə b ə b aː m ɪ n aː m ə t̪ ə ɾ ɔː ɟ aː t̪ ʊ eː ɛː
# --------------------------------------------------
# [294/299] Processed: 281474976734095.wav
# Transcription:
# t̪ ə l aː b ə d̪ ɪ b ɔː
# --------------------------------------------------
# [295/299] Processed: 281474976733615.wav
# Transcription:
# n aː b s ə t̪ ɔː k ɔː iː aː ə ɟ ə ɾ uː ɾ iː b aː t̪ ə n aː eː ɛː k ə ɪ oː t̪ iː m oː ʈ iː ɾ iː t̪ iː ɾ ɪ b aː ɟ eː ɦ ɔː ɾ ə oː t̪ iː eː ɛː ɟ s ɪ k ɪ s ə ɟ aː k oː t̪ eː ɾ ə ɾ ɪ b eː k eː b aː ə s ə ɟ aː k uː ɡ uː ɾ ə p uː ɟ ɔː ɟ aː t̪ ʊ eː ɛː ə m aː eː ɟ aː b ʊ ɾ ə p uː ɟ eː m eː ɟ oː b ə ɾ ə n aː ɟ aː d̪ ə ɾ ə n iː ɦ oː t̪ ɪ eː ɛː b ʊ b aː k iː aː k eː b ə n ə d̪ ə ɡ̤ ə ɾ k eː b aː k iː b eː ɛː n ə l ɛː ɟ aː t̪ ɪ ɛː ɟ aː k ɔː iː oː ɟ ə n ɔː ɡ oː ɪ ə b ə n ə k eː ɡ̤ ə ɾ ə m ɪ b ʊ aː k ɪ n p ɛː p ə t̪ iː b aː n d̪ eː t̪ ʊ eː ɛː b ɪ ɾ ɪ ə b ɪ n aː k eː b ə n t̪ ə ɡ̤ ə ɾ ə k eː ɦ oː ɡ uː ɾ ɔː p uː ɟ ɪ b eː k ə l ə ɟ aː n ə p ə t̪ ʊ eː ɛː p ɪ ɾ ə b aː ɡ uː ɾ eː k oː p uː s ə t̪ eː ɛː t̪ ə eː ɛː ɔː p ɪ ə l eː ɟ aː t̪ ə eː ɛː t̪ ɪ eː ɛː k ə p ə ɾ ə m ə p ə ɾ aː ɪ ɛː ɟ ɦ oː t̪ ɪ aː ɪ ɾ ə iː eː ɛː s ɔː ə l t̪ ɪ aː ɪ ɾ ə eː ɛː p ɔː t̪ ɔː k oː iː k aː ɾ ə ɟ ə ɾ uː ɾ iː k ə iː b aː t̪ ə t̪ iː n aː ɪ n ə
# --------------------------------------------------
# [296/299] Processed: 281474976733619.wav
# Transcription:
# s ɪ ɾ ə ɪ ɾ aː m ə m ə ɖ ə b ʊ l aː eː ɟ aː t̪ ə eː ɛː ɔː ɾ ə k iː aː d̪ aː b ə ɖ aː b uː ɾ aː ɛː t̪ ʊ ɾ ɪ s t̪ eː d̪ aː ɾ ə n ə k uː b ʊ l aː ɪ l eː t̪ ə p aː t̪ ɪ m ɪ n ɛː t̪ ʊ ə ɡ ə ɾ ə k oː iː k ə m ə m ə ɾ ə k ɔː ɟ aː n ɪ l aː n ə oː t̪ ʊ eː ɛː t̪ ɔː ɛː s ɪ ɾ ɪ p ə b ɪ ɾ aː m ə b ə ɾ ə n uː k uː b ʊ l aː ɔː ɟ aː t̪ ʊ m eː ɛː ɦ ɔː t̪ eː ɾ ɛː p ɾ aː m ə m ɪ ɾ ɪ aː t̪ ɪ b ɾ aː m ə m ə l oː ɪ b ɪ t̪ eː ɾ ə m ə b ə ɾ ə l ɪ k ə k ə b aː t̪ ə ɔː ɟ aː t̪ ʊ eː ɛː
# --------------------------------------------------
# [297/299] Processed: 281474976733606.wav
# Transcription:
# b ɪ aː ə m ɪ n ə ɾ eː ɾ iː t̪ iː ɾ ɪ b aː ɟ ə ɦ oː t̪ ə eː ɛː ɟ ɪ n ə m ɪ ɛː ɡ ə ɾ ə m ə b ə t̪ aː eː ɛː t̪ ɔː p ɛː l ɔː eː ɛː l ə ɡ ʊ n ə d̪ iː k aː ɟ aː m ɪ m ɔː ɖ iː k eː ɡ̤ ə ɾ ə m ɪ l ə ɡ ʊ n ə k iː ɟ aː t̪ ɪ ɛː ə ɔː b ə aː m ɛː p ə ɖ ɪ t̪ ɪ t̪ ə p uː ɟ ə m ə ɾ ə l ə b ə m ɔː ɖ iː k oː aː t̪ ə m eː ɛː eː ɡ ə n aː ɾ ɪ ɛː ə ɔː eː k ə p ə ɖ aː ɟ ə d̪ eː t̪ ʊ eː ɔː ɾ ə eː k ə b ə ɖ iː s iː p ə ɾ aː t̪ ɪ ɦ oː t̪ ɪ eː ɛː p ə ɾ aː t̪ ə m ɪ k uː p uː ɟ ə t̪ ə eː ɛː b aː p ɪ s aː t̪ iː aː b ə n aː ɪ d̪ eː t̪ ə ɛː p ɪ s ə ɟ aː k uː b eː p ə ɾ aː ɔː ɾ ə k aː p ə ɖ aː l ɪ t̪ aː ə l ɛː k ə ɛː m ɔː ɖ iː b aː eː ɛː ɟ ɪ t̪ eː uː oː ɛː ɡ eː b s ɪ m ə m ɔː ɖ aː b aː eː k eː ɟ aː ɟ aː t̪ ə eː ɛː m ə m b eː ɛː p aː t̪ eː ɦ oː t̪ ɪ eː ɛː ɔː ə ɾ ə m ɔː ɖ aː k ɔː ə ʈ iː s aː k ə t̪ ə eː ɛː ɔː p ə ɖ ɪ t̪ ə k uː ɟ aː k ə t̪ ʊ eː ɛː ɔː ɾ ə b aː t̪ eː b aː oː t̪ ʊ eː ɛː d̪ uː s eː ɛː n ə m ə b ə ɾ ɪ p ɛː t̪ eː l ɪ b aː ɔː k aː s ə t̪ eː l ə m ɪ ɛː s aː ɦ oː t̪ ʊ eː ɛː t̪ eː l ə k eː k aː ɾ ɪ k ɾ ə m ə m ɪ m ɔː ɖ aː m ɔː ɖ iː k eː ɟ ə ɾ ə n ə m ɪ b ɪ n ə b ɪ n ə k eː ɔː ə ɾ ɪ b aː b iː ɦ oː t̪ iː eː ɛː ɔː b ɪ n ə k eː ə k iː ɾ ə s ʊ aː k eː n ɪ ɛː ɦ oː t̪ iː eː ɛː b eː s ɪ p ɛː l ɪ t̪ eː l ə p uː ɟ ɪ b ɪ ɟ aː t̪ iː m ə n ə d̪ ə ɾ ə n ə b ə ɛː ɔː t̪ eː l ə p uː ɟ ɪ eː ɛː p ɪ ə l ɔː ə t̪ ə k ɪ aː t̪ iː eː ɛː m ɛː ɟ ə b aː ɟ eː b aː eː n ə k eː s ə ɡ ə m ɪ p ɪ ɾ ə l ɔː ə ʈ ə k aː ɪ k ɪ b ɔː ɖ aː m oː ɖ ə n ɪ p ɪ t̪ eː ɾ ɪ ə ɖ ə t̪ ʊ eː aː p ɛː p ə eː ɛː ɡ̤ ə ɾ ə ɡ ə m ɪ t̪ ɪ eː ɛː ə ɖ ə b eː p ɔː k aː ɾ ə n ə ɟ iː ɦ oː t̪ ʊ m eː ɛː ɟ aː s ɛː k ɪ b ɪ n ə k iː oː b ɖ iː eː ɛː b aː b ə s ə ɾ iː ɾ ə p eː b ɪ n ə k eː p ɛː m ɛː b ʊ n ə k ə ɾ ə m ə k ɪ ɟ iː k ɔː ɾ ə b aː k eː b aː d̪ ə m ɪ oː t̪ eː k ə t̪ aː iː t̪ ɔː t̪ aː iː k uː t̪ ɔː ɾ aː t̪ ə m ɪ ɦ oː t̪ ɪ eː ɛː t̪ aː iː k ə m ə n ə n aː ɛː s ɪ ɔː ɾ ə t̪ ɛː p ə ɪ m ə n ɔː ɾ ə n ə ɟ ə n ə k eː l aː ɛː k ə t̪ iː eː ɛː ɟ aː s ɪ b eː ɟ ə ɡ ɪ s aː k eː ɛː ɔː n ɛː ə ɾ ə m ə d̪ ə l ɛː s aː k ɪ m p ɪ aː k ɔː ɪ t̪ iː ɟ oː b aː ɦ ə d̪ ɔː ɖ ə ɛː ɟ aː t̪ eː ɟ aː s ə b ə s k ɪ b aː k eː b aː d̪ ə ɦ oː t̪ ʊ eː ɛː k ɪ ə m ɛː d̪ iː l ə ɡ aː ɟ iː ɟ aː t̪ ɪ eː ɛː m ɔː ɖ ɔː m ɛː n iː l ə ɡ aː ɡ ə eː ɦ ɔː m ɔː ɖ iː m ɛː n ɪ l ə ɡ aː ɾ ə iː d̪ ɔː n ɔː ɾ ə k eː ɛː m ɛː d̪ iː l ə ɡ aː iː ɟ aː t̪ ɪ eː ɛː d̪ ɔː n aː d̪ ɔː n ɔː aː t̪ ə n ə p ɪ ɛː ɔː ɾ ə p aː ɪ n ə p ɛː ɟ aː s ɪ b eː ɔː ɾ ə s ʊ m ə d̪ ə aː l ə ɡ ɪ ɟ ɪ k aː ɾ ə n ə ɦ oː t̪ ʊ eː ɛː ə m ɪ ɛː d̪ iː l ə ɡ aː ɪ b eː k ɔː ɾ ə ɾ ɪ s t̪ eː d̪ aː ɾ ə ɦ ə p ə ɛː p ɪ aː t̪ ə n ə b ɪ ɛː m ɪ ɛː n eː l ə ɡ aː ɪ ɟ eː t̪ ə eː ɛː b aː k eː b aː d̪ ɪ m ɪ ɛː m ɛː d̪ iː l ə ɡ aː b eː k iː b aː d̪ m ɪ ɛː s ɪ n aː ɪ d̪ ə aː n ɔː ɾ ə k ə k ə l eː t̪ ə eː ɛː ɟ aː s n ɛː k ə b ɪ aː k ɔː n ə n d̪ ə l ɛː s ə k ɪ s ɪ b ə l oː ə m ɔː ɖ aː b aː k eː ɡ̤ ə ɾ ə m ɪ ɛː aː l ə ɔː ɡ oː t̪ ʊ eː m ɔː ɖ iː l aː eː k eː k ə ɾ ə m ɪ ɛː l aː ə ɦ oː t̪ ʊ eː ɛː p ɪ ɾ ə b aː k eː b aː t̪ ə m ɪ b ɪ aː b aː eː d̪ ɪ n m ɔː ɖ aː m ɔː ɖ iː k eː s ə iː ɟ ə aː ɡ ɛː ɪ p ɛː m ɪ n t̪ ə eː ɛː b ɪ n ə k iː p ə ɾ ɪ b aː ɾ ə s eː d̪ ɔː n ə t̪ ə iː aː ɾ ɛː k ɪ aː t̪ ə eː ɛː t̪ ɔː iː aː ɾ ɛː k ɪ p ɪ ɾ ə b ɪ n ə k iː ɛː m aː l aː ɦ oː t̪ ɪ eː ɛː ɟ ɛː ɪ m aː l aː k ɪ b aː t̪ ə m eː k aː s iː ɾ b aː d̪ ə k oː k aː ɾ ɪ k ɾ ə m ə l t̪ ʊ eː ɛː s ɪ b l oː ɡ ə aː ɾ iː k ə b aː d̪ ə d̪ eː ɛː t̪ ə eː ɛː m ə eː ɛː b aː p ɪ ɟ aː eː ɛː k eː b ə n ə p ɛː ɟ aː ɪ ɟ aː ɪ ə k ɪ s ɪ b ə n ɛː aː s iː ɾ ə b aː m ə b ɪ n ɔː n ɔː m ɔː ɖ aː m ɔː ɖ iː k ə t̪ ʊ s ə b ə ɟ l oː aː s iː ɾ ə b aː d̪ eː t̪ ə ɛː aː s iː k ə b aː d̪ ə d̪ ɛː b eː k eː b aː d̪ ə m ɪ s ə b ə l oː ɡ ə p ə ɛː p ɛː k ə aː ɾ ə ɛː ə ɾ ɛː ɟ aː t̪ ə eː ɛː ɔː ɟ oː k ə ɾ iː b iː k ə ɾ iː b iː ɾ ɪ s t̪ eː d̪ aː ɾ ɪ ɛː b eː ɾ uː k ɪ ɟ aː t̪ ə eː ɛː k ɾ ə ɾ aː t̪ ə m ɪ ɛː k ə n aː n aː n ə oː ʊ ɾ aː ə s aː b eː ɾ eː k ɪ s ə m ɪ k ə m ɪ j aː d̪ aː n ə oː t̪ ʊ eː m ɔː ɖ iː k ɔː ɟ b ɔː ɖ iː k ɪ m ə m iː p aː p aː k ə t̪ ə eː ɛː k ə m ɛː n aː n ə k eː b aː d̪ ə m ɪ b ɪ ɾ aː eː ɛː ɟ aː t̪ ɪ eː ɛː t̪ ɔː ɪ t̪ eː p ə ɡ ə s ə n ə oː t̪ ə eː ɛː t̪ eː ɾ iː t̪ iː ɾ ɪ b aː ɟ ə ɦ oː t̪ ʊ eː ɛː ɔː m ə k ...
# --------------------------------------------------
# [298/299] Processed: 281474976733592.wav
# Transcription:
# b ɛː s ɪ t̪ ɛː ə s ɔː k ə uː n aː eː ɛː k ɪ k ə uː iː l oː ɡ ə n ə k oː b ʊ l aː ɟ ə ɛː l eː k ɪ n ə b ə aː ɟ ə n ə m ɪ t̪ ʊ eː ɛː p ɔː b aː ʈ aː ɛː n ə p ɛː ɡ̤ ə ɾ ə k eː ɟ oː b ə ɾ ɦ oː t̪ ə eː ɛː ɟ oː b ʊ ɟ ə ɾ ə ɡ oː ɦ oː t̪ ə eː ɛː ɟ s ə m ə ɟ ə d̪ aː ɾ ə b ʊ ɟ ɪ ɾ uː ɦ oː t̪ ə eː ɛː b eː t̪ ɔː uː n iː ə ɛː ɟ ɛː s ɪ k eː ə ɡ ə ɾ ə b ʊ aː eː ɛː d̪ aː d̪ iː b uː aː j aː p ɪ d̪ aː d̪ iː eː ɛː n aː n iː eː ɛː ɟ eː l oː ɡ ə ɦ oː t̪ ə eː ɛː ɟ eː b ə aː k ɪ ɟ ə n ə m ɪ ɟ ə n ə m b eː p ɪ ɛː b ʊ l aː ɟ aː t̪ ə eː ɛː ə ɟ ə n ə m b eː k ɪ b aː ə n aː m ə d̪ ə ɾ eː ə b aː d̪ ɪ n aː t̪ ɔː s ə b eː ɟ ɪ s t̪ eː ɾ aː ɾ ə m ə ɡ uː b ʊ l aː ɔː ɟ aː t̪ ʊ eː ɛː ɟ ɪ t̪ eː ɾ ɪ s t̪ eː d̪ aː ɾ ɛː ɟ ɪ t̪ ʊ uː m ɪ l ɪ b eː b aː eː uː ɪ n ə ɪ b ə n ə k oː k ʊ l aː ɔː ɟ aː t̪ ʊ eː ɛː
# --------------------------------------------------
# [299/299] Processed: 281474976733588.wav
# Transcription:
# k ə d̪ iː
# --------------------------------------------------
#
# ✅ All transcriptions saved to: /content/drive/MyDrive/Dataset_allosaurus/validate/transcriptions.csv

# %%
import pandas as pd

# Step 1: Load the CSV file
file_path = '/content/drive/MyDrive/transcriptions.csv'  # <-- change this to your file path
df = pd.read_csv(file_path)

# Step 2: Modify the 'ID' column to remove ".wav"
df['ID'] = df['ID'].str.replace('.wav', '', regex=False)

# Step 3: Save the modified DataFrame back to CSV
output_path = '/content/drive/MyDrive/transcriptions.csv'  # <-- change this if you want a different output name
df.to_csv(output_path, index=False)

print(f"File saved as {output_path}")
# Out:
# File saved as /content/drive/MyDrive/transcriptions.csv

# %%
import pandas as pd

# Load the two CSV files (ASR and Ground Truth in IPA format)
# Load the two CSV files (ASR and Ground Truth in IPA format)
asr_df = pd.read_csv('/content/drive/MyDrive/transcriptions.csv')
gt_df = pd.read_csv('/content/drive/MyDrive/validate_IPA.csv', delimiter='\t')

# Check the column names to ensure they are loaded correctly
print("ASR DataFrame columns:", asr_df.columns)
print("Ground Truth DataFrame columns:", gt_df.columns)

# Rename Ground Truth columns to match ASR DataFrame column names
gt_df.columns = ['ID', 'Transcription']

# Now merge on 'ID'
merged_df = pd.merge(gt_df, asr_df, on='ID', suffixes=('_gt', '_asr'))

# Preprocessing: lowercasing and removing punctuations (optional, depends on what you want)
def preprocess(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    return text

merged_df['Transcription_gt_clean'] = merged_df['Transcription_gt'].apply(preprocess)
merged_df['Transcription_asr_clean'] = merged_df['Transcription_asr'].apply(preprocess)

# Function to compare two sentences
def analyze_differences(gt, asr):
    gt_words = gt.split()
    asr_words = asr.split()

    matcher = difflib.SequenceMatcher(None, gt_words, asr_words)

    substitutions = []
    insertions = []
    deletions = []

    for opcode, i1, i2, j1, j2 in matcher.get_opcodes():
        if opcode == 'replace':
            substitutions.append((gt_words[i1:i2], asr_words[j1:j2]))
        elif opcode == 'insert':
            insertions.append(asr_words[j1:j2])
        elif opcode == 'delete':
            deletions.append(gt_words[i1:i2])

    return substitutions, insertions, deletions

# Apply to all rows
error_summary = []
for idx, row in merged_df.iterrows():
    subs, ins, dels = analyze_differences(row['Transcription_gt_clean'], row['Transcription_asr_clean'])
    error_summary.append({
        'ID': row['ID'],
        'Substitutions': subs,
        'Insertions': ins,
        'Deletions': dels
    })

error_df = pd.DataFrame(error_summary)

# Count error types overall
all_subs = []
all_ins = []
all_dels = []

for errors in error_summary:
    all_subs.extend(errors['Substitutions'])
    all_ins.extend(errors['Insertions'])
    all_dels.extend(errors['Deletions'])

substitution_counter = Counter([f"{' '.join(gt)} --> {' '.join(asr)}" for gt, asr in all_subs])
insertion_counter = Counter([phoneme for ins in all_ins for phoneme in ins])
deletion_counter = Counter([phoneme for dels in all_dels for phoneme in dels])

# Print some basic analysis
print("\nTop Substitutions:")
for pair, count in substitution_counter.most_common(10):
    print(f"{pair}: {count} times")

print("\nTop Insertions (ASR added extra phonemes):")
for phoneme, count in insertion_counter.most_common(10):
    print(f"{phoneme}: {count} times")

print("\nTop Deletions (ASR missed phonemes):")
for phoneme, count in deletion_counter.most_common(10):
    print(f"{phoneme}: {count} times")

# Save detailed error report
error_df.to_csv('error_analysis_report_ipa.csv', index=False)
print("\nDetailed error report saved as 'error_analysis_report_ipa.csv'")
# Out:
# ASR DataFrame columns: Index(['ID', 'Transcription'], dtype='object')
# Ground Truth DataFrame columns: Index(['ID', 'IPA_Transcription'], dtype='object')
#
# Top Substitutions:
# ɪ --> ə: 24 times
# ə --> ɪ: 19 times
# oː --> ɔː: 18 times
# eː --> ɪ: 17 times
# ɦ --> eː: 15 times
# ɪ --> eː: 13 times
# ɔː --> ə: 12 times
# aː --> ə: 12 times
# uː --> ʊ: 10 times
# ɛː --> ə: 10 times
#
# Top Insertions (ASR added extra phonemes):
# ə: 263 times
# ɪ: 115 times
# aː: 110 times
# eː: 96 times
# k: 90 times
# ɛː: 74 times
# t: 71 times
# ɾ: 68 times
# b: 57 times
# n: 47 times
#
# Top Deletions (ASR missed phonemes):
# ə: 246 times
# eː: 101 times
# ɪ: 93 times
# ɾ: 72 times
# ɛː: 69 times
# t: 63 times
# ɦ: 58 times
# aː: 52 times
# k: 45 times
# b: 43 times
#
# Detailed error report saved as 'error_analysis_report_ipa.csv'

# %%
import pandas as pd
import difflib
from collections import Counter
import re

# Homophone dictionary for IPA phonemes (extend this as necessary)
ipa_homophones = {
    'eː': ['ɛː', 'ɛ'],
    'oː': ['ɔː'],
    'ʈʃ': ['ʈʂ'],
    'ʈʂ': ['ʈʃ'],
    'kʰ': ['k'],
    'g': ['ɡ'],
    'b': ['bː'],
    'd̪ʰ': ['d̪']
}

# Function to check if two IPA phonemes are homophones
def are_homophones(ipa1, ipa2):
    for key, values in ipa_homophones.items():
        if ipa1 == key and ipa2 in values:
            return True
        if ipa2 == key and ipa1 in values:
            return True
    return False

# Load the two CSV files (ASR and Ground Truth in IPA format)
asr_df = pd.read_csv('/content/drive/MyDrive/transcriptions.csv')
gt_df = pd.read_csv('/content/drive/MyDrive/validate_IPA.csv', delimiter='\t')

# Rename Ground Truth columns to match ASR DataFrame column names
gt_df.columns = ['ID', 'Transcription']

# Merge on 'ID'
merged_df = pd.merge(gt_df, asr_df, on='ID', suffixes=('_gt', '_asr'))

# Function to compare two IPA transcriptions
def analyze_differences(gt, asr):
    gt_phonemes = gt.split()
    asr_phonemes = asr.split()

    matcher = difflib.SequenceMatcher(None, gt_phonemes, asr_phonemes)

    substitutions = []
    insertions = []
    deletions = []

    for opcode, i1, i2, j1, j2 in matcher.get_opcodes():
        if opcode == 'replace':
            substitutions.append((gt_phonemes[i1:i2], asr_phonemes[j1:j2]))
        elif opcode == 'insert':
            insertions.append(asr_phonemes[j1:j2])
        elif opcode == 'delete':
            deletions.append(gt_phonemes[i1:i2])

    return substitutions, insertions, deletions

# Function to calculate Word Error Rate (WER)
def calculate_wer(gt, asr):
    gt_phonemes = gt.split()
    asr_phonemes = asr.split()

    # Get the Levenshtein distance (edit distance) between the two
    matcher = difflib.SequenceMatcher(None, gt_phonemes, asr_phonemes)
    edits = matcher.get_opcodes()

    substitutions = sum(1 for tag, i1, i2, j1, j2 in edits if tag == 'replace')
    insertions = sum(1 for tag, i1, i2, j1, j2 in edits if tag == 'insert')
    deletions = sum(1 for tag, i1, i2, j1, j2 in edits if tag == 'delete')

    # Calculate WER
    wer = (substitutions + insertions + deletions) / len(gt_phonemes)
    return wer, substitutions, insertions, deletions

# Apply to all rows
error_summary = []
for idx, row in merged_df.iterrows():
    subs, ins, dels = analyze_differences(row['Transcription_gt'], row['Transcription_asr'])

    # Calculate WER for the current row
    wer, sub_count, ins_count, del_count = calculate_wer(row['Transcription_gt'], row['Transcription_asr'])

    # Count homophones in substitutions
    homophone_matches = []
    for gt_sub, asr_sub in subs:
        if any(are_homophones(gt, asr) for gt in gt_sub for asr in asr_sub):
            homophone_matches.append((gt_sub, asr_sub))

    error_summary.append({
        'ID': row['ID'],
        'Substitutions': subs,
        'Insertions': ins,
        'Deletions': dels,
        'WER': wer,
        'Homophone Matches': homophone_matches
    })

error_df = pd.DataFrame(error_summary)

# Count error types overall
all_subs = []
all_ins = []
all_dels = []
all_homophones = []

for errors in error_summary:
    all_subs.extend(errors['Substitutions'])
    all_ins.extend(errors['Insertions'])
    all_dels.extend(errors['Deletions'])
    all_homophones.extend(errors['Homophone Matches'])

substitution_counter = Counter([f"{' '.join(gt)} --> {' '.join(asr)}" for gt, asr in all_subs])
insertion_counter = Counter([phoneme for ins in all_ins for phoneme in ins])
deletion_counter = Counter([phoneme for dels in all_dels for phoneme in dels])
homophone_counter = Counter([f"{' '.join(gt)} --> {' '.join(asr)}" for gt, asr in all_homophones])

# Print some basic analysis
print("\nTop Substitutions:")
for pair, count in substitution_counter.most_common(10):
    print(f"{pair}: {count} times")

print("\nTop Insertions (ASR added extra phonemes):")
for phoneme, count in insertion_counter.most_common(10):
    print(f"{phoneme}: {count} times")

print("\nTop Deletions (ASR missed phonemes):")
for phoneme, count in deletion_counter.most_common(10):
    print(f"{phoneme}: {count} times")

print("\nTop Homophone Matches (substituted homophones):")
for pair, count in homophone_counter.most_common(10):
    print(f"{pair}: {count} times")

# Save detailed error report
error_df.to_csv('/content/drive/MyDrive/error_analysis_report_with_wer_and_homophones_ipa.csv', index=False)
print("\nDetailed error report saved as 'error_analysis_report_with_wer_and_homophones_ipa.csv'")
# Out:
# Top Substitutions:
# ɪ --> ə: 24 times
# ə --> ɪ: 19 times
# oː --> ɔː: 18 times
# eː --> ɪ: 17 times
# ɦ --> eː: 15 times
# ɪ --> eː: 13 times
# ɔː --> ə: 12 times
# aː --> ə: 12 times
# uː --> ʊ: 10 times
# ɛː --> ə: 10 times
#
# Top Insertions (ASR added extra phonemes):
# ə: 273 times
# aː: 115 times
# ɪ: 110 times
# eː: 103 times
# k: 93 times
# ɛː: 77 times
# t̪: 75 times
# ɾ: 74 times
# b: 55 times
# m: 50 times
#
# Top Deletions (ASR missed phonemes):
# ə: 244 times
# eː: 100 times
# ɪ: 92 times
# ɾ: 71 times
# ɛː: 68 times
# t̪: 62 times
# ɦ: 58 times
# aː: 52 times
# k: 45 times
# b: 43 times
#
# Top Homophone Matches (substituted homophones):
# oː --> ɔː: 18 times
# ɔː --> oː: 7 times
# ɛː --> eː: 7 times
# eː --> ɛː: 5 times
# ɦ oː --> ɔː: 2 times
# eː --> ɪ ɛː: 2 times
# eː ɦ ə --> ɛː: 2 times
# ə oː --> ɔː: 1 times
# ɛː --> ə eː ə: 1 times
# j oː --> iː ɦ ɔː: 1 times
#
# Detailed error report saved as 'error_analysis_report_with_wer_and_homophones_ipa.csv'

# %%
import json
import torch
import os

def load_model(model_name):
    # Path to the models.json file
    models_json_path = '/content/drive/MyDrive/uni2510_model.json'  # Update this if it's located elsewhere

    # Check if the models.json file exists
    if not os.path.exists(models_json_path):
        raise FileNotFoundError(f"{models_json_path} not found. Ensure the file is present.")

    # Load the model registry (models.json)
    with open(models_json_path, 'r') as f:
        model_registry = json.load(f)

    # Check if the model_name exists in the registry
    if model_name in model_registry['models']:
        model_path = model_registry['models'][model_name]
        print(f"Loading model: {model_name} from {model_path}")

        # Ensure that the model directory exists
        if not os.path.exists(model_path):
            raise FileNotFoundError(f"Model directory {model_path} does not exist.")

        # Ensure that the model file (model.pt) exists
        model_file_path = os.path.join(model_path, 'model.pt')
        if not os.path.exists(model_file_path):
            raise FileNotFoundError(f"Model file {model_file_path} not found.")

        # Load the model using PyTorch (or your preferred framework)
        try:
            # You can modify this to load the model in a different way if needed
            model = torch.load(model_file_path)
            print(f"Model {model_name} loaded successfully.")
            return model

        except Exception as e:
            raise RuntimeError(f"Error loading model {model_name}: {e}")

    else:
        raise ValueError(f"Model {model_name} not found in the model registry.")

# Example usage:
try:
    model_name = "uni2510"  # Use your model name here
    model = load_model(model_name)
    # Perform further operations with the model here
except Exception as e:
    print(f"Error: {e}")
# Out:
# Loading model: uni2510 from /content/drive/MyDrive/uni2510
# Model uni2510 loaded successfully.

# %%
# Out:
# Collecting allosaurus@ git+https://github.com/pswiercz/allosaurus.git
#   Cloning https://github.com/pswiercz/allosaurus.git to /tmp/pip-install-mmsrllk2/allosaurus_b7ed71d331b24489bdeee87d91bd4067
#   Running command git clone --filter=blob:none --quiet https://github.com/pswiercz/allosaurus.git /tmp/pip-install-mmsrllk2/allosaurus_b7ed71d331b24489bdeee87d91bd4067
#   fatal: could not read Username for 'https://github.com': No such device or address
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet https://github.com/pswiercz/allosaurus.git /tmp/pip-install-mmsrllk2/allosaurus_b7ed71d331b24489bdeee87d91bd4067 did not run successfully.
#   │ exit code: 128
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git clone --filter=blob:none --quiet https://github.com/pswiercz/allosaurus.git /tmp/pip-install-mmsrllk2/allosaurus_b7ed71d331b24489bdeee87d91bd4067 did not run successfully.
# │ exit code: 128
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import torch
import os
from allosaurus.predictor import Predictor

# 1. Load the Predictor
def load_predictor():
    # Path to the custom model directory (where model.pt exists)
    model_dir = "/content/drive/MyDrive/"
    model_tag = "uni2510"

    # Create the Predictor with the model
    predictor = Predictor(model_tag=model_tag, model_dir=model_dir)
    print(f"Loaded predictor with model: {model_tag}")
    return predictor

# 2. Recognize phonemes from a wav file
def recognize_phonemes(predictor, wav_path):
    phoneme_sequence = predictor.predict(wav_path, lang_id="eng")  # assuming the language ID is "eng"
    return phoneme_sequence

# Convert phoneme sequence to Hindi text
def ipa_to_hindi(phoneme_sequence):
    # Define your custom IPA to Hindi mapping
    ipa_to_hindi_map = {
        "ə": "अ",
        "aː": "आ",
        "ɪ": "इ",
        "iː": "ई",
        "ʊ": "उ",
        "uː": "ऊ",
        "eː": "ए",
        "oː": "ओ",
        "ɛː": "ऐ",
        "ɔː": "औ",

        "k": "क",
        "kʰ": "ख",
        "ɡ": "ग",
        "ɡ̤": "घ",
        "ŋ": "ङ",

        "ʈʃ": "च",
        "ʈʃʰ": "छ",
        "ɟ": "ज",
        "ɟʱ": "झ",
        "ɲ": "ञ",

        "ʈ": "ट",
        "ʈʰ": "ठ",
        "ɖ": "ड",
        "ɖʱ": "ढ",
        "ɳ": "ण",

        "t̪": "त",
        "t̪ʰ": "थ",
        "d̪": "द",
        "d̪ʱ": "ध",
        "n": "न",

        "p": "प",
        "pʰ": "फ",
        "b": "ब",
        "bʱ": "भ",
        "m": "म",

        "j": "य",
        "ɾ": "र",
        "l": "ल",
        "ʋ": "व",

        "ʃ": "श",
        "ʂ": "ष",
        "s": "स",
        "h": "ह",

        "ŋ": "ङ",
        "ɦ": "ह",

        "æ": "ऐ",
        "f": "फ़",
        "z": "ज़",
        "ʒ": "ज़",
    }

    phonemes = phoneme_sequence.split()
    hindi_output = ""

    for phoneme in phonemes:
        hindi_char = ipa_to_hindi_map.get(phoneme, phoneme)  # fallback: keep phoneme if no mapping
        hindi_output += hindi_char

    return hindi_output

# 4. Full Pipeline: WAV to Hindi Text
def process_audio(wav_path):
    predictor = load_predictor()

    # Step 1: Recognize phonemes
    phoneme_sequence = recognize_phonemes(predictor, wav_path)
    print(f"🎯 Phoneme Sequence: {phoneme_sequence}")

    # Step 2: Convert phonemes to Hindi
    hindi_text = ipa_to_hindi(phoneme_sequence)
    print(f"📝 Hindi Text: {hindi_text}")

    return hindi_text

# 5. Example Usage
if __name__ == "__main__":
    wav_file = "/path/to/your_audio.wav"  # ✅ Set your correct WAV file path here
    hindi_text = process_audio(wav_file)
    print("\n✅ Final Hindi Output:", hindi_text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-8c0c2d37a386> in <cell line: 0>()
#       1 import torch
#       2 import os
# ----> 3 from allosaurus.predictor import Predictor
#       4
#       5 # 1. Load the Predictor
#
# ModuleNotFoundError: No module named 'allosaurus.predictor'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import os
import torchaudio
from allosaurus.app import read_recognizer

# Load the model
def load_model():
    # Load the default recognizer (or you can pass a specific model name)
    model = read_recognizer()
    print("Model loaded successfully.")
    return model

# Function to perform transcription on audio
def transcribe_audio(model, audio_file_path):
    # Just pass the path to model.recognize
    transcription = model.recognize(audio_file_path)
    return transcription

# Example usage
model = load_model()

# Path to the WAV file you want to transcribe
audio_file_path = '/content/drive/MyDrive/Dataset_allosaurus/validate/audio/281474976714320.wav'

# Transcribe the audio
transcription = transcribe_audio(model, audio_file_path)

print("Transcription:", transcription)
# Out:
# Model loaded successfully.
# Transcription: m ɪ s̪ a d ɪ d uə e ɾ ɒ w e
